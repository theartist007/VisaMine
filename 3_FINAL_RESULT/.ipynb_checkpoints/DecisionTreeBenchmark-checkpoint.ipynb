# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Load cleaned up version of dataset from 2012 to 2018.  Drop geographic information about employer and worksite to reduce dimensionality

# %%
df = pd.read_pickle('/Users/minse_chang/PycharmProjects/Udacity_ML_Capstone/data/H1B_15-18_new.pickle')
df = df[['CASE_STATUS','WAGE_LOWER_THAN_PW','PREVAILING_WAGE','SOC_CODE','EMPLOYER_NAME']]
# df = df[['CASE_STATUS','WAGE_LOWER_THAN_PW','PREVAILING_WAGE','SOC_CODE']]
df['CASE_STATUS'] = df['CASE_STATUS'].apply(lambda x : 1 if x=='DENIED' else 0)

# %%
df['WAGE_LOWER_THAN_PW'] = df['WAGE_LOWER_THAN_PW'].astype(int)
df.head(10)
# Out:
#     CASE_STATUS  WAGE_LOWER_THAN_PW  PREVAILING_WAGE SOC_CODE  \
# 1             0                   0     45727.334000  25-1032
# 3             0                   0     70413.266200  17-2072
# 4             0                   0    103390.078300  15-1131
# 6             0                   0    142938.994400  15-1132
# 7             0                   0     68372.286500  15-2031
# 8             0                   0    108717.110000  15-1121
# 9             1                   0        23.962574  13-2011
# 10            0                   0    105150.463300  15-1132
# 11            1                   1    368080.500000  13-2011
# 12            1                   1     71456.694400  15-1021
#
#                          EMPLOYER_NAME
# 1                 UNIVERSITYOFOKLAHOMA
# 3            OMRONOILFIELDANDMARINEINC
# 4            FEDERALHOMELOANMORTGAGECO
# 6                            VMWAREINC
# 7   FEDERALHOMELOANMORTGAGECORPORATION
# 8                            VMWAREINC
# 9                  IMAEXTRADINGCOMPANY
# 10                           VMWAREINC
# 11                              LHBINC
# 12      INTERNATIONALSOLUTIONSGROUPINC

# %%
ones_df = df[df['CASE_STATUS']==1]
zeros_df = df[df['CASE_STATUS']==0]

# %%
df = pd.concat([ones_df, zeros_df.sample(frac=0.02, random_state=99)])

# %%
ones_df.head()
print(ones_df.shape)
# Out:
# (37310, 5)

# %%
zeros_df.head()
print(zeros_df.shape)
# Out:
# (2424938, 5)

# %% [markdown]
# We will use column 'CASE_STATUS' as our label.  DENIED will be 1 and CERTIFIED will be 0 after it gets incoded by label_encoder.
#
# Normalize PREVAILING_WAGE using minmax scaler since it varies quite a bit.

# %%
scaler = MinMaxScaler()
X = df.drop(columns='CASE_STATUS')

# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(df['CASE_STATUS'])


X[['PREVAILING_WAGE']] = scaler.fit_transform(X[['PREVAILING_WAGE']])
X = pd.get_dummies(X)

# %%
y = df['CASE_STATUS']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Check value counts to verify stratify split

# %%
# print(y_train.value_counts())
# print(y_test.value_counts())
X_train.head()
# Out:
#         WAGE_LOWER_THAN_PW  PREVAILING_WAGE  SOC_CODE_11-1011  \
# 595927                   0         0.000062                 0
# 624033                   0         0.000085                 0
# 144585                   0         0.000095                 0
# 102684                   0         0.000069                 0
# 447271                   0         0.000073                 0
#
#         SOC_CODE_11-1021  SOC_CODE_11-2011  SOC_CODE_11-2021  \
# 595927                 0                 0                 0
# 624033                 0                 0                 0
# 144585                 0                 0                 0
# 102684                 0                 0                 0
# 447271                 0                 0                 0
#
#         SOC_CODE_11-2022  SOC_CODE_11-2031  SOC_CODE_11-3011  \
# 595927                 0                 0                 0
# 624033                 0                 0                 0
# 144585                 0                 0                 0
# 102684                 0                 0                 0
# 447271                 0                 0                 0
#
#         SOC_CODE_11-3021            ...              EMPLOYER_NAME_ZYNGA INC.  \
# 595927                 0            ...                                     0
# 624033                 0            ...                                     0
# 144585                 0            ...                                     0
# 102684                 0            ...                                     0
# 447271                 0            ...                                     0
#
#         EMPLOYER_NAME_ZYNGA, INC.  EMPLOYER_NAME_ZYPE INC  \
# 595927                          0                       0
# 624033                          0                       0
# 144585                          0                       0
# 102684                          0                       0
# 447271                          0                       0
#
#         EMPLOYER_NAME_ZYPE INC.  EMPLOYER_NAME_ZYSTEMSGO, INC.  \
# 595927                        0                              0
# 624033                        0                              0
# 144585                        0                              0
# 102684                        0                              0
# 447271                        0                              0
#
#         EMPLOYER_NAME_ZYTO TECHNOLOGIES, INC.  EMPLOYER_NAME_ZYWIE INC.  \
# 595927                                      0                         0
# 624033                                      0                         0
# 144585                                      0                         0
# 102684                                      0                         0
# 447271                                      0                         0
#
#         EMPLOYER_NAME_[24]7.AI, INC.  EMPLOYER_NAME_ÉTUDES LLC  \
# 595927                             0                         0
# 624033                             0                         0
# 144585                             0                         0
# 102684                             0                         0
# 447271                             0                         0
#
#         EMPLOYER_NAME_ÉTUDES, LLC
# 595927                          0
# 624033                          0
# 144585                          0
# 102684                          0
# 447271                          0
#
# [5 rows x 32454 columns]

# %% [markdown]
# Train DecisionTreeClassifier and predict using only 4 features from X_test

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)

clf_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print("** Random Forest Classifier Stats (OVERALL testset)")
print(classification_report(y_test, clf_pred))
# Out:
# ** Random Forest Classifier Stats (OVERALL testset)
#              precision    recall  f1-score   support
#
#           0       0.75      0.81      0.78      9742
#           1       0.72      0.64      0.68      7420
#
# avg / total       0.73      0.74      0.73     17162

# %% [markdown]
# Print out score statsfor the entire dataset

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, fbeta_score, accuracy_score, confusion_matrix

print("** Decision Tree Classifier Scores (OVERALL testset)")
print("Precision: %s"% precision_score(y_test, clf_pred))
print("Recall: %s"% recall_score(y_test, clf_pred))
print("Accuracy score: %s"% accuracy_score(y_test, clf_pred))
print("F-1 score: %s"% f1_score(y_test, clf_pred))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_test, clf_pred, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_test, clf_pred, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_test, clf_pred))
# Out:
# ** Decision Tree Classifier Scores (OVERALL testset)
# Precision: 0.7189831024509058
# Recall: 0.636522911051213
# Accuracy score: 0.7352872625568115
# F-1 score: 0.675244835227679
# F-beta score with beta=0.5: 0.7008250237416904
# F-beta score with beta=0.2: 0.7154184508724403
# Confusion Matrix:
# [[7896 1846]
#  [2697 4723]]

# %%
df.head()
# Out:
#     CASE_STATUS  WAGE_LOWER_THAN_PW  PREVAILING_WAGE SOC_CODE  \
# 9             1                   0        23.962574  13-2011
# 11            1                   1    368080.500000  13-2011
# 12            1                   1     71456.694400  15-1021
# 37            1                   0     21338.000000  15-2041
# 55            1                   0     74696.869700  15-1021
#
#                           EMPLOYER_NAME
# 9                 IMAEX TRADING COMPANY
# 11                            LHB, INC.
# 12  INTERNATIONAL SOLUTIONS GROUP, INC.
# 37                            LHB, INC.
# 55  INTERNATIONAL SOLUTIONS GROUP, INC.

# %% [markdown]
# Evaluate stats for testset with label 1 (DENIED cases only)

# %%
import numpy as np
ones_index = list(y_test.nonzero()[0])

# %%
x_ones = X_test.iloc[ones_index]
y_ones = np.take(y_test.values, ones_index)

clf_pred_oneonly = clf.predict(x_ones)

# %%
print("** Decision Tree Classifier Scores (Only rows with label DENIED->1)")
print("Precision: %s"% precision_score(y_ones, clf_pred_oneonly))
print("Recall: %s"% recall_score(y_ones, clf_pred_oneonly))
print("Accuracy score: %s"% accuracy_score(y_ones, clf_pred_oneonly))
print("F-1 score: %s"% f1_score(y_ones, clf_pred_oneonly))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_ones, clf_pred_oneonly, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_ones, clf_pred_oneonly, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_ones, clf_pred_oneonly))
# Out:
# ** Decision Tree Classifier Scores (Only rows with label DENIED->1)
# Precision: 1.0
# Recall: 0.636522911051213
# Accuracy score: 0.636522911051213
# F-1 score: 0.7778967306266985
# F-beta score with beta=0.5: 0.8974992398905443
# F-beta score with beta=0.2: 0.9785091039483644
# Confusion Matrix:
# [[   0    0]
#  [2697 4723]]

# %% [markdown]
# Evaluate stats for testset with label 0 (CERTIFIED cases only)

# %%
zeros_index = np.arange(len(y_test))[(y_test==0)]

x_zeros = X_test.iloc[zeros_index]
y_zeros = np.take(y_test.values, zeros_index)
clf_pred_zeroonly = clf.predict(x_zeros)

# %%
print("** Decision Tree Classifier Scores (Only rows with label CERTIFIED->0)")
print("Precision: %s"% precision_score(y_zeros, clf_pred_zeroonly))
print("Recall: %s"% recall_score(y_zeros, clf_pred_zeroonly))
print("Accuracy score: %s"% accuracy_score(y_zeros, clf_pred_zeroonly))
print("F-1 score: %s"% f1_score(y_zeros, clf_pred_zeroonly))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_zeros, clf_pred_zeroonly, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_zeros, clf_pred_zeroonly, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_zeros, clf_pred_zeroonly))
# Out:
# ** Decision Tree Classifier Scores (Only rows with label CERTIFIED->0)
# Precision: 0.0
# Recall: 0.0
# Accuracy score: 0.8105111886676247
# F-1 score: 0.0
# F-beta score with beta=0.5: 0.0
# F-beta score with beta=0.2: 0.0
# Confusion Matrix:
# [[7896 1846]
#  [   0    0]]

# %%
import operator
nonzero_features = {}
for i in range(len(clf.feature_importances_)):
    if clf.feature_importances_[i] > 0.0:
        nonzero_features[list(X_train.columns)[i]] = clf.feature_importances_[i]
sorted_result = sorted(nonzero_features.items(), key=operator.itemgetter(1)) 
for i in range(len(sorted_result)):
    print(sorted_result[-(i+1)])
# Out:
# (u'PREVAILING_WAGE', 0.18962907678420166)
# ('WAGE_LOWER_THAN_PW', 0.11245432982346015)
# (u'EMPLOYER_NAME_INFOSYS LIMITED', 0.011695117371107145)
# ('SOC_CODE_15-1121', 0.011211457060237899)
# ('SOC_CODE_15-1199', 0.010339803088269543)
# ('SOC_CODE_15-1132', 0.00992767344191534)
# ('SOC_CODE_15-1131', 0.009396137272003818)
# (u'EMPLOYER_NAME_TATA CONSULTANCY SERVICES LIMITED', 0.0067021037711386166)
# ('SOC_CODE_15-1133', 0.0029931750349588334)
# ('SOC_CODE_13-1111', 0.0025560385978159253)
# ('SOC_CODE_15-1141', 0.002349335517094268)
# ('SOC_CODE_15-1142', 0.0023245161739404857)
# ('SOC_CODE_15-2031', 0.0022820328424360977)
# (u'EMPLOYER_NAME_CONSULTADD INC', 0.002229979980389235)
# (u'EMPLOYER_NAME_DELOITTE CONSULTING LLP', 0.00206820251730964)
# ('SOC_CODE_29-1123', 0.0018440040134659838)
# (u'EMPLOYER_NAME_GLOBALLOGIC,INC.', 0.0016767410410562715)
# (u'EMPLOYER_NAME_ACCENZ LLC', 0.0016017064362577875)
# ('SOC_CODE_15-2041', 0.0014999232519278976)
# (u'EMPLOYER_NAME_HCL AMERICA, INC.', 0.001442913540259314)
# (u'EMPLOYER_NAME_ACCENTURE LLP', 0.0014242594052307396)
# (u'EMPLOYER_NAME_ERNST & YOUNG U.S. LLP', 0.0013943870060576212)
# (u'EMPLOYER_NAME_MICROSOFT CORPORATION', 0.0013024794693603798)
# (u'EMPLOYER_NAME_GOOGLE INC.', 0.0012513095675660934)
# (u'EMPLOYER_NAME_CAPGEMINI AMERICA INC', 0.0012343503645438267)
# (u'EMPLOYER_NAME_TECH MAHINDRA (AMERICAS),INC.', 0.0012029555304352813)
# ('SOC_CODE_19-1042', 0.0011711667420492206)
# (u'EMPLOYER_NAME_L&T TECHNOLOGY SERVICES LIMITED', 0.001064011768849494)
# ('SOC_CODE_19-1029', 0.0010557511076460982)
# (u'EMPLOYER_NAME_GOOGLE LLC', 0.0009988984212243018)
# (u'EMPLOYER_NAME_INTEL CORPORATION', 0.0009712532405457946)
# ('SOC_CODE_17-2141', 0.0009698766313090923)
# ('SOC_CODE_13-2051', 0.0009673887706678623)
# (u'EMPLOYER_NAME_IBM CORPORATION', 0.000959941798640008)
# (u'EMPLOYER_NAME_AMAZON CORPORATE LLC', 0.000892554522265761)
# (u'EMPLOYER_NAME_NCS PEARSON, INC.', 0.0008902573220101867)
# (u'EMPLOYER_NAME_ORANGEINFOTECHLLC', 0.0008445621122139269)
# ('SOC_CODE_19-2031', 0.0008185515515480614)
# (u'EMPLOYER_NAME_NEW YORK SOFTWARE GROUP LLC', 0.0008121812480048941)
# (u'EMPLOYER_NAME_BOSTONTECHSOFT', 0.0007793366757496194)
# (u'EMPLOYER_NAME_NTT DATA SERVICES, LLC', 0.0007785144402983891)
# (u'EMPLOYER_NAME_JPMORGAN CHASE & CO.', 0.0007620661964332821)
# (u'EMPLOYER_NAME_CISCO SYSTEMS, INC.', 0.0007507961817086235)
# (u'EMPLOYER_NAME_DELOITTE & TOUCHE LLP', 0.0007479965537226996)
# ('SOC_CODE_25-1071', 0.0007404576930018569)
# (u'EMPLOYER_NAME_VMWARE, INC.', 0.0007333169633739422)
# ('SOC_CODE_19-1021', 0.0007224478905073599)
# ('SOC_CODE_17-2071', 0.0007042436275238205)
# ('SOC_CODE_17-2072', 0.000702244535154586)
# ('SOC_CODE_29-1069', 0.0006982701720916849)
# (u'EMPLOYER_NAME_GOLDMAN, SACHS & CO.', 0.0006893539724777697)
# (u'EMPLOYER_NAME_SYNTEL CONSULTING INC.', 0.0006739000486692806)
# ('SOC_CODE_13-2011', 0.0006730087346175931)
# (u'EMPLOYER_NAME_POPULUS GROUP LLC', 0.0006645957291252102)
# (u'EMPLOYER_NAME_FACEBOOK, INC.', 0.0006612585542250896)
# (u'EMPLOYER_NAME_COGNIZANT TECHNOLOGY SOLUTIONS US CORP', 0.000652619013211209)
# (u'EMPLOYER_NAME_MANAGEMENT HEALTH SYSTEMS LLC', 0.0006481334879364824)
# ('SOC_CODE_15-1122', 0.0006477601140694949)
# ('SOC_CODE_11-2021', 0.0006464526926005323)
# (u'EMPLOYER_NAME_APPLE INC.', 0.0006389812029393683)
# (u'EMPLOYER_NAME_WIPRO LIMITED', 0.0006366208533668523)
# ('SOC_CODE_17-2112', 0.0006237393596341032)
# (u'EMPLOYER_NAME_KPMG LLP', 0.00059546904194964)
# (u'EMPLOYER_NAME_PRICEWATERHOUSECOOPERS LLP', 0.0005931285104785108)
# (u'EMPLOYER_NAME_NTT DATA, INC.', 0.0005894444688275951)
# ('SOC_CODE_11-1021', 0.0005866223625759421)
# (u'EMPLOYER_NAME_TESLA, INC.', 0.0005854232359080715)
# (u'EMPLOYER_NAME_VIRTUSA IT LLC', 0.0005755820751783322)
# (u'EMPLOYER_NAME_BAIN BRIDGE INFO TECH LLC', 0.0005752697138447473)
# (u'EMPLOYER_NAME_QUALCOMM ATHEROS, INC.', 0.0005624177470350566)
# ('SOC_CODE_13-2099', 0.0005594979466618729)
# (u'EMPLOYER_NAME_TECHSAYON LLC', 0.0005427077087355736)
# (u'EMPLOYER_NAME_SELORASOFTLLC', 0.000542237457946266)
# ('SOC_CODE_15-1111', 0.0005382617763986196)
# ('SOC_CODE_11-3031', 0.0005325981125741234)
# ('SOC_CODE_11-1011', 0.0005276596782335418)
# (u'EMPLOYER_NAME_COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION', 0.0005151259091405037)
# ('SOC_CODE_13-1199', 0.0005126594423280322)
# (u'EMPLOYER_NAME_ORIANA IT LLC', 0.0005079941546992413)
# (u'EMPLOYER_NAME_PROSOFT TECHNOLOGIES INC', 0.0005074719513049001)
# (u'EMPLOYER_NAME_QUALCOMM TECHNOLOGIES, INC.', 0.0004950706081851112)
# (u'EMPLOYER_NAME_HCL GLOBAL SYSTEMS INC', 0.0004912388815687072)
# (u'EMPLOYER_NAME_EUCLID TECHNOLOGIES LLC', 0.0004902526866566568)
# ('SOC_CODE_29-1131', 0.0004859962034583786)
# (u'EMPLOYER_NAME_PAYPAL, INC.', 0.0004851649152744061)
# ('SOC_CODE_23-1011', 0.00048471122401445084)
# (u'EMPLOYER_NAME_BTREE SOLUTIONS INC', 0.00048004489655631427)
# (u'EMPLOYER_NAME_AMAZON.COM SERVICES, INC.', 0.0004771694339761762)
# ('SOC_CODE_11-9199', 0.0004730339620578457)
# ('SOC_CODE_11-9021', 0.0004595354667095214)
# (u'EMPLOYER_NAME_KEYMOUZ TECHNOLOGIES INC', 0.0004591435047616021)
# (u'EMPLOYER_NAME_MAYO CLINIC', 0.0004579436620189012)
# ('SOC_CODE_11-9041', 0.00045403364291312585)
# ('SOC_CODE_11-3021', 0.00045141853262353597)
# (u'EMPLOYER_NAME_BANK OF AMERICA N.A.', 0.00044734689477268693)
# (u'EMPLOYER_NAME_T-MOBILE USA, INC.', 0.00044386027361111615)
# (u'EMPLOYER_NAME_CUMMINS INC.', 0.00043412101646643486)
# (u'EMPLOYER_NAME_AKKEN INC', 0.00043109410999644)
# ('SOC_CODE_29-1021', 0.000431059104318331)
# (u'EMPLOYER_NAME_AKAMAI TECHNOLOGIES, INC.', 0.00043079096348074355)
# (u'EMPLOYER_NAME_BROADCOM CORPORATION', 0.00042228376498390166)
# (u'EMPLOYER_NAME_DUKE UNIVERSITY AND MEDICAL CENTER', 0.0004118951202958137)
# ('SOC_CODE_19-2032', 0.00041151484793032494)
# (u'EMPLOYER_NAME_CYIENT, INC.', 0.0004108172370574891)
# (u'EMPLOYER_NAME_EXPERIS US, INC.', 0.0004101284607949913)
# (u'EMPLOYER_NAME_REVEREIT LLC', 0.00040825961255789)
# (u'EMPLOYER_NAME_EBAY INC.', 0.00040691420671938204)
# ('SOC_CODE_19-4021', 0.00040664610570911565)
# (u'EMPLOYER_NAME_BLUE SHIELD OF CALIFORNIA', 0.0004066267301645939)
# (u'EMPLOYER_NAME_BLACKROCK FINANCIAL MANAGEMENT, INC.', 0.0004023788230996809)
# (u'EMPLOYER_NAME_NOVISYNC SOLUTIONS, INC.', 0.0004006596998080607)
# (u'EMPLOYER_NAME_KFORCE INC.', 0.0003974340249810899)
# ('SOC_CODE_13-1081', 0.0003962765266323108)
# (u'EMPLOYER_NAME_SRISHTI I2I BIZ SOLUTIONS INC', 0.00039271341561426625)
# ('SOC_CODE_29-1066', 0.0003919785361216004)
# ('SOC_CODE_11-3051', 0.0003901583012911804)
# (u'EMPLOYER_NAME_DELOITTE &AMP; TOUCHE LLP', 0.00037846966730503316)
# (u'EMPLOYER_NAME_SYMANTEC CORPORATION', 0.0003746231150094498)
# (u'EMPLOYER_NAME_BROOKHAVEN NATIONAL LABORATORY', 0.000371143466312793)
# ('SOC_CODE_19-3011', 0.0003705120096019541)
# (u'EMPLOYER_NAME_LARSEN & TOUBRO INFOTECH LIMITED', 0.00037007620697211636)
# (u'EMPLOYER_NAME_SYNTEL INC', 0.0003693324735899442)
# (u'EMPLOYER_NAME_ADOBE SYSTEMS INCORPORATED', 0.0003672394998989566)
# (u'EMPLOYER_NAME_DALLAS INDEPENDENT SCHOOL DISTRICT', 0.000363412686693948)
# ('SOC_CODE_15-1143', 0.00036277221910918514)
# (u'EMPLOYER_NAME_EXLSERVICE.COM, LLC', 0.00036072901387497756)
# (u'EMPLOYER_NAME_IBM INDIA PRIVATE LIMITED', 0.00035963612501794303)
# (u'EMPLOYER_NAME_HEWLETT PACKARD ENTERPRISE COMPANY', 0.00035753771104568723)
# ('SOC_CODE_17-2199', 0.00035739653024517763)
# (u'EMPLOYER_NAME_DELL PRODUCTS L.P.', 0.0003566765044173616)
# (u'EMPLOYER_NAME_UNIVERSITY OF WASHINGTON', 0.0003530233994008375)
# (u'EMPLOYER_NAME_GLOBAL TECHNOLOGY AND SERVICES INC', 0.0003521981013124361)
# ('SOC_CODE_17-1011', 0.00035063122877193527)
# ('SOC_CODE_15-2021', 0.0003487103487618623)
# (u'EMPLOYER_NAME_STATE STREET BANK AND TRUST COMPANY', 0.0003482507943938027)
# (u'EMPLOYER_NAME_BAYLOR COLLEGE OF MEDICINE', 0.0003441708095617894)
# (u'EMPLOYER_NAME_IT CORRIDOR CORPORATION', 0.000341837174930065)
# (u'EMPLOYER_NAME_P2P SOFTTEK LLC', 0.0003405133290788767)
# (u'EMPLOYER_NAME_SCHLUMBERGER TECHNOLOGY CORPORATION', 0.00033941405423342327)
# ('SOC_CODE_13-1041', 0.0003390899691776084)
# (u'EMPLOYER_NAME_PRICEWATERHOUSECOOPERS ADVISORY SERVICES LLC', 0.0003390481857234705)
# (u'EMPLOYER_NAME_TRUSTEES OF THE UNIVERSITY OF PENNSYLVANIA', 0.0003379283680724706)
# (u'EMPLOYER_NAME_VSYS, INC.', 0.0003377282215647966)
# ('EMPLOYER_NAME_Unknown', 0.0003354303769523221)
# (u'EMPLOYER_NAME_EMC CORPORATION', 0.00033386396451290677)
# (u'EMPLOYER_NAME_DOYENSYS, INC.', 0.0003330806436113194)
# ('SOC_CODE_17-2031', 0.00033279432605732277)
# (u'EMPLOYER_NAME_UNIVERSITY OF MICHIGAN', 0.0003321429700538928)
# ('SOC_CODE_27-3031', 0.00033002417525174275)
# (u'EMPLOYER_NAME_EXPEDIA, INC.', 0.00032960512725900353)
# (u'EMPLOYER_NAME_CAPGEMINI AMERICA, INC.', 0.00032960146389437816)
# (u'EMPLOYER_NAME_MCKINSEY & COMPANY, INC. UNITED STATES', 0.00032758472859694185)
# (u'EMPLOYER_NAME_DELOITTE TAX LLP', 0.00032522285035996415)
# (u'EMPLOYER_NAME_LOS ALAMOS NATIONAL SECURITY, LLC', 0.0003247315964992306)
# (u'EMPLOYER_NAME_CITADEL LLC', 0.00032439386116096065)
# (u'EMPLOYER_NAME_RLGH LLC', 0.0003234210199864315)
# (u'EMPLOYER_NAME_SOURCEONE TECHNOLOGY SOLUTIONS, INC', 0.0003231875383781701)
# (u'EMPLOYER_NAME_INTEGRATED RESOURCES, INC', 0.00032181534211907746)
# ('SOC_CODE_13-1161', 0.00032152548429651925)
# (u'EMPLOYER_NAME_VERIZON DATA SERVICES LLC', 0.00031962894872566175)
# (u'EMPLOYER_NAME_OPTUM SERVICES, INC.', 0.00031880002700808056)
# (u'EMPLOYER_NAME_SALESFORCE.COM INC.', 0.00031482168854275044)
# (u'EMPLOYER_NAME_PIXAWARE TECHNOLOGIES, LLC', 0.00031416991668591256)
# (u'EMPLOYER_NAME_NHK INTERNATIONAL CORPORATION', 0.0003118552527626229)
# (u'EMPLOYER_NAME_GOLDMAN SACHS SERVICES LLC', 0.0003100337611018588)
# (u'EMPLOYER_NAME_VIRTUEGROUP LLC', 0.00030990701697885447)
# (u'EMPLOYER_NAME_SEARS HOLDINGS MANAGEMENT CORPORATION', 0.00030872318321000636)
# ('SOC_CODE_17-2121', 0.0003077368588300148)
# (u'EMPLOYER_NAME_THE OHIO STATE UNIVERSITY', 0.0003055376710751948)
# ('SOC_CODE_29-1065', 0.00030417280082150824)
# (u'EMPLOYER_NAME_UT-BATTELLE, LLC (OAK RIDGE NATIONAL LABORATORY)', 0.0003034939631905873)
# (u'EMPLOYER_NAME_NORTHWESTERN UNIVERSITY', 0.00029769263758296267)
# ('SOC_CODE_17-2051', 0.0002964191470705393)
# (u'EMPLOYER_NAME_VIRTUSA CORPORATION', 0.0002957472906829198)
# ('SOC_CODE_27-3099', 0.0002948455761012033)
# (u'EMPLOYER_NAME_TWITTER, INC.', 0.0002946361745879579)
# (u'EMPLOYER_NAME_ORACLE AMERICA, INC.', 0.00029435706954094996)
# ('SOC_CODE_17-2011', 0.00029382089583693396)
# (u'EMPLOYER_NAME_EMBLEMATIC TECH SOLUTIONS, LLC', 0.0002936852378893177)
# (u'EMPLOYER_NAME_MEDTRONIC, INC.', 0.0002936506786941963)
# ('SOC_CODE_17-2131', 0.000291550702075782)
# ('SOC_CODE_13-1071', 0.00028884376505114006)
# ('SOC_CODE_25-1011', 0.0002887031015949711)
# (u'EMPLOYER_NAME_JONAM SYSTEMS INC', 0.00028821422771548814)
# (u'EMPLOYER_NAME_COMPUNNEL SOFTWARE GROUP, INC.', 0.00028806102089682013)
# (u'EMPLOYER_NAME_ALTAIR PRODUCTDESIGN, INC.', 0.0002854802977015618)
# (u'EMPLOYER_NAME_AMGEN INC.', 0.00028519720102036913)
# (u'EMPLOYER_NAME_UNIVERSITY OF HOUSTON SYSTEM', 0.00028305343901946294)
# (u'EMPLOYER_NAME_VAREX IMAGING CORPORATION', 0.00028215591466614396)
# (u'EMPLOYER_NAME_ADVANCED MICRO DEVICES, INC.', 0.000281881708501017)
# (u'EMPLOYER_NAME_GENERAL HOSPITAL CORPORATION', 0.00028107290466153524)
# (u'EMPLOYER_NAME_M SOFTWARE SOLUTIONS, INC.', 0.0002796413609909811)
# (u'EMPLOYER_NAME_PAMTEN, INC.', 0.0002794634971890235)
# (u'EMPLOYER_NAME_STARBUCKS COFFEE COMPANY', 0.00027747274052086773)
# ('SOC_CODE_11-9051', 0.00027675783511427703)
# (u'EMPLOYER_NAME_MICHIGAN TECHNOLOGY GROUP, INC', 0.00027540812733710667)
# (u'EMPLOYER_NAME_DAZ SYSTEMS, INC.', 0.00027524515744374096)
# (u'EMPLOYER_NAME_INDIANA UNIV. PURDUE UNIV. INDIANAPOLIS', 0.0002743588905591304)
# (u'EMPLOYER_NAME_MCAFEE, LLC', 0.0002742414539490383)
# (u'EMPLOYER_NAME_MICRON TECHNOLOGY, INC.', 0.0002738642556638495)
# (u'EMPLOYER_NAME_GOLDMAN SACHS & CO. LLC', 0.00027162588845274595)
# (u'EMPLOYER_NAME_TANISHA SYSTEMS INC', 0.00027101797500915346)
# ('SOC_CODE_27-1029', 0.0002698535362928295)
# (u'EMPLOYER_NAME_COMPETITIVE COMPUTER INFORMATION TECHNOLOGIES, INC', 0.0002696163567879957)
# (u'EMPLOYER_NAME_SEMETRIX INC', 0.0002681748771101497)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER AT HOUSTON', 0.0002670836118214467)
# (u'EMPLOYER_NAME_GLOBUS IT INCORPORATED', 0.00026605546821939296)
# ('SOC_CODE_29-1062', 0.00026578506945250217)
# (u'EMPLOYER_NAME_IGATE TECHNOLOGIES INC.', 0.00026412079640496396)
# (u'EMPLOYER_NAME_WEATHERFORD INTERNATIONAL, LLC', 0.0002638838530317085)
# (u'EMPLOYER_NAME_SYNOPSYS, INC.', 0.0002631095765102137)
# (u'EMPLOYER_NAME_CITIBANK, N.A.', 0.0002624378960415711)
# (u'EMPLOYER_NAME_UNIVERSITY OF CALIFORNIA, DAVIS', 0.00026083717548729314)
# (u'EMPLOYER_NAME_ZEBRA TECHNOLOGIES CORPORATION', 0.00025664611736569103)
# (u'EMPLOYER_NAME_VISA U.S.A. INC.', 0.0002554837386736344)
# (u'EMPLOYER_NAME_UBER TECHNOLOGIES, INC.', 0.0002554062731368577)
# (u'EMPLOYER_NAME_CAREMARK, LLC', 0.0002546981824903679)
# (u'EMPLOYER_NAME_INOVALON, INC.', 0.00025228503812066547)
# (u'EMPLOYER_NAME_MERRILL LYNCH', 0.00025160499156478026)
# (u'EMPLOYER_NAME_SAP LABS, LLC', 0.0002509302695811283)
# (u'EMPLOYER_NAME_SHYFT ANALYTICS, INC.', 0.00024991979847060954)
# (u'EMPLOYER_NAME_THOUGHTWORKS, INC.', 0.0002492555013982134)
# (u'EMPLOYER_NAME_SAPIENT CORPORATION', 0.00024877464727096225)
# (u'EMPLOYER_NAME_BEST BUY CO., INC.', 0.0002477991869771953)
# (u'EMPLOYER_NAME_UNIVERSITY OF NORTH CAROLINA AT CHARLOTTE', 0.0002471588004789042)
# (u'EMPLOYER_NAME_MORGAN STANLEY SMITH BARNEY LLC', 0.00024707905862786714)
# (u'EMPLOYER_NAME_ITEAM INC', 0.0002461693535937843)
# (u'EMPLOYER_NAME_INNOVA SOLUTIONS, INC.', 0.0002457236431779509)
# ('SOC_CODE_17-2171', 0.0002455044244665106)
# (u'EMPLOYER_NAME_SYSINTELLI INC', 0.00024484042204412325)
# ('SOC_CODE_25-1121', 0.00024447327042492935)
# (u'EMPLOYER_NAME_POPULUS GROUP', 0.00024383075946435602)
# (u'EMPLOYER_NAME_NATIONAL OILWELL VARCO, L.P.', 0.00024373228082011524)
# (u'EMPLOYER_NAME_OMNI NETWORKS INC', 0.00024320038933288942)
# (u'EMPLOYER_NAME_HEWLETT-PACKARD COMPANY', 0.0002425108886954214)
# ('SOC_CODE_13-2041', 0.0002424028791228725)
# (u'EMPLOYER_NAME_SLALOM, LLC', 0.00024211432592083105)
# (u'EMPLOYER_NAME_NIIT TECHNOLOGIES LIMITED', 0.00024102839457708095)
# (u'EMPLOYER_NAME_BDO USA, LLP', 0.00023976748934459986)
# (u'EMPLOYER_NAME_CITICORP CREDIT SERVICES, INC. (USA)', 0.00023901795784581347)
# (u'EMPLOYER_NAME_NORTH CAROLINA STATE UNIVERSITY', 0.0002367153622416053)
# (u'EMPLOYER_NAME_IMPETUS TECHNOLOGIES, INC.', 0.00023624457933056582)
# ('SOC_CODE_19-2012', 0.00023613230391915968)
# (u'EMPLOYER_NAME_TIBCO SOFTWARE, INC.', 0.00023598482651723452)
# (u'EMPLOYER_NAME_SOFTERION INC.,', 0.0002357296917462426)
# (u'EMPLOYER_NAME_ADS ALLIANCE DATA SYSTEMS, INC.', 0.00023514676480773642)
# (u'EMPLOYER_NAME_BRIO SYSTEMS INC.', 0.0002349493144266654)
# (u'EMPLOYER_NAME_DELL MARKETING L.P.', 0.0002348588993964289)
# (u'EMPLOYER_NAME_UNIVERSITY OF FLORIDA', 0.00023455618183935233)
# ('SOC_CODE_29-1122', 0.00023332268871205622)
# (u'EMPLOYER_NAME_GLOBAL SOFT SYSTEMS, INC.', 0.00023294508147442272)
# (u'EMPLOYER_NAME_RUTGERS, THE STATE UNIVERSITY OF NEW JERSEY', 0.00023232625768621745)
# (u'EMPLOYER_NAME_TALENTSPACE INC', 0.0002322406486166358)
# ('SOC_CODE_41-9031', 0.00023193352877259527)
# ('SOC_CODE_35-1011', 0.0002318241287267509)
# (u'EMPLOYER_NAME_CIBER, INC.', 0.00023149223790473633)
# ('SOC_CODE_27-1014', 0.00022972473766833023)
# (u'EMPLOYER_NAME_AECOM TECHNICAL SERVICES, INC.', 0.00022842680977127862)
# (u'EMPLOYER_NAME_SYNEREN TECHNOLOGIES CORPORATION', 0.00022829114335329504)
# (u'EMPLOYER_NAME_SIEMENS MEDICAL SOLUTIONS USA, INC.', 0.00022807884407404153)
# (u'EMPLOYER_NAME_INFOSTRETCH CORPORATION', 0.0002273837564866673)
# ('SOC_CODE_13-1051', 0.00022639610876701551)
# ('SOC_CODE_29-1063', 0.00022630887267204686)
# (u'EMPLOYER_NAME_CAPGEMINI U.S. LLC', 0.00022511623494872183)
# ('SOC_CODE_17-2041', 0.00022497210007427023)
# (u'EMPLOYER_NAME_NIKE, INC.', 0.00022488492514959727)
# (u'EMPLOYER_NAME_DATA-CORE SYSTEMS, INC', 0.00022393124785243082)
# (u'EMPLOYER_NAME_JAITRA, INC.', 0.000223708397324528)
# (u'EMPLOYER_NAME_MASTECH DIGITAL TECHNOLOGIES, INC., A MASTECH DIGITAL, INC. COMPANY', 0.00022356058955360717)
# (u'EMPLOYER_NAME_SOGETI USA LLC', 0.00022203255421201414)
# (u'EMPLOYER_NAME_NVIDIA CORPORATION', 0.00022199689418445553)
# (u'EMPLOYER_NAME_MPHASIS CORPORATION', 0.00022132791905235782)
# (u'EMPLOYER_NAME_SALESFORCE.COM, INC.', 0.00022099722427667025)
# ('SOC_CODE_25-2022', 0.00022092135668369577)
# ('SOC_CODE_11-2022', 0.00021984328370716028)
# (u'EMPLOYER_NAME_CIRRUS LOGIC, INC.', 0.00021891418928954973)
# (u'EMPLOYER_NAME_VEROTECH SOLUTIONS,LLC', 0.00021891413619407342)
# (u'EMPLOYER_NAME_UNIVERSITY OF CALIFORNIA, LOS ANGELES', 0.00021879667067978175)
# (u'EMPLOYER_NAME_THE PENNSYLVANIA STATE UNIVERSITY', 0.00021789989738499435)
# (u'EMPLOYER_NAME_PURDUE UNIVERSITY', 0.00021566873373882702)
# (u'EMPLOYER_NAME_NEW YORK UNIVERSITY SCHOOL OF MEDICINE', 0.0002154994991059647)
# (u'EMPLOYER_NAME_PPD DEVELOPMENT, L.P.', 0.00021518251942792042)
# (u'EMPLOYER_NAME_TESLA MOTORS, INC.', 0.00021455617265346894)
# (u'EMPLOYER_NAME_INTELLITRO INC', 0.00021445973552447218)
# ('SOC_CODE_27-1025', 0.00021333118872964647)
# ('SOC_CODE_29-1051', 0.00021291181177920392)
# (u'EMPLOYER_NAME_MODEL N, INC.', 0.00021259489258465222)
# (u'EMPLOYER_NAME_MOTOROLA SOLUTIONS, INC.', 0.00021244189207615511)
# (u'EMPLOYER_NAME_LINKEDIN CORPORATION', 0.00020936632588841193)
# (u'EMPLOYER_NAME_SYSTEMS TECHNOLOGY GROUP, INC.', 0.0002091505453583634)
# (u'EMPLOYER_NAME_DELOITTE TRANSACTIONS AND BUSINESS ANALYTICS LLP', 0.00020886781733765083)
# (u'EMPLOYER_NAME_NETROCON SYSTEMS LLC', 0.00020866365735943402)
# (u'EMPLOYER_NAME_YAHOO HOLDINGS, INC.', 0.00020842013081986385)
# ('SOC_CODE_19-2042', 0.00020839040364880292)
# (u'EMPLOYER_NAME_ECLINICALWORKS, LLC', 0.00020827371792650484)
# (u'EMPLOYER_NAME_CADENCE DESIGN SYSTEMS, INC.', 0.0002080970667607897)
# (u'EMPLOYER_NAME_SPK CONSULTANTS INC.', 0.00020794265906986782)
# ('SOC_CODE_17-2061', 0.00020790882678559008)
# (u'EMPLOYER_NAME_BAYSTATE MEDICAL CENTER, INC.', 0.00020777034434197003)
# ('SOC_CODE_23-2011', 0.00020694665760672237)
# (u'EMPLOYER_NAME_HEADSTRONG SERVICES LLC', 0.00020691237441043415)
# (u'EMPLOYER_NAME_PEOPLE TECH GROUP INC.', 0.00020660475615438663)
# (u'EMPLOYER_NAME_UST GLOBAL INC.', 0.00020585639531390878)
# ('SOC_CODE_25-1032', 0.0002052982599876794)
# (u'EMPLOYER_NAME_GENENTECH, INC.', 0.0002044171847460633)
# ('SOC_CODE_25-1041', 0.00020433534384476062)
# (u'EMPLOYER_NAME_DIVERSANT LLC', 0.00020411103912680679)
# (u'EMPLOYER_NAME_UNIVERSITY OF TEXAS MEDICAL BRANCH AT GALVESTON', 0.00020404308458377306)
# (u'EMPLOYER_NAME_VIRTUOSO TECHNOLOGIES, INC.', 0.00020390478562931882)
# (u'EMPLOYER_NAME_COMCAST CABLE COMMUNICATIONS, LLC', 0.000203174226525194)
# (u'EMPLOYER_NAME_APPISOFT, INC.', 0.00020305769151329566)
# ('SOC_CODE_21-1021', 0.00020278278519033174)
# (u'EMPLOYER_NAME_RAISER TECHNOLOGIES INC', 0.00020257162266636681)
# (u'EMPLOYER_NAME_COLUMBIA UNIVERSITY', 0.00020241866260478113)
# (u'EMPLOYER_NAME_MEGAPUTER INTELLIGENCE INC.', 0.0002016801494034631)
# (u'EMPLOYER_NAME_SYSTEM SOFT TECHNOLOGIES LLC', 0.00020139907930846266)
# (u'EMPLOYER_NAME_ANTHEM, INC.', 0.00020110743306178818)
# ('SOC_CODE_11-3071', 0.0002002198085976053)
# (u'EMPLOYER_NAME_MUFG UNION BANK, N.A.', 0.00020003315101558268)
# (u'EMPLOYER_NAME_MORGAN STANLEY SERVICES GROUP INC', 0.00019989648621009906)
# (u'EMPLOYER_NAME_ADI WORLDLINK, LLC', 0.0001993681684039572)
# (u'EMPLOYER_NAME_VSYS. INC.', 0.00019916857882901285)
# (u'EMPLOYER_NAME_MORGAN STANLEY & CO. LLC', 0.00019840241385854385)
# (u'EMPLOYER_NAME_OASYS TECHNOLOGIES INC', 0.00019797030573686118)
# (u'EMPLOYER_NAME_BLACK & VEATCH CORPORATION', 0.00019776993093292985)
# ('SOC_CODE_29-2011', 0.0001976722420885925)
# (u'EMPLOYER_NAME_VIGNA SOLUTIONS, INC.', 0.00019742095320991938)
# (u'EMPLOYER_NAME_UNIVERSITY OF UTAH', 0.0001973929803663455)
# (u'EMPLOYER_NAME_UNIVERSITY OF LOUISVILLE', 0.0001963895067516815)
# (u'EMPLOYER_NAME_SERVICENOW, INC.', 0.00019637556559545542)
# ('SOC_CODE_25-1122', 0.0001962180500521544)
# ('SOC_CODE_25-1126', 0.00019412278491633556)
# (u'EMPLOYER_NAME_B.I.G. ARCHITECTURE D.P.C.', 0.00019400843519823234)
# (u'EMPLOYER_NAME_SMART SOURCE TECHNOLOGIES, INC.', 0.00019384151051687654)
# (u'EMPLOYER_NAME_MICHIGAN STATE UNIVERSITY', 0.00019355182552069342)
# (u'EMPLOYER_NAME_THE GAP, INC.', 0.00019245877070292385)
# ('SOC_CODE_15-2011', 0.0001922994849374768)
# ('SOC_CODE_25-1042', 0.0001921022005367233)
# (u'EMPLOYER_NAME_BLIZZARD ENTERTAINMENT, INC.', 0.00019144253348678917)
# (u'EMPLOYER_NAME_ANIRA SOLUTIONS INC', 0.00019114511593688085)
# (u'EMPLOYER_NAME_MINDTREE LIMITED', 0.0001911210373656643)
# (u'EMPLOYER_NAME_TRINUS CORPORATION', 0.00019112010191304812)
# (u'EMPLOYER_NAME_MINDBOARD, INC.', 0.00019049424774484386)
# (u'EMPLOYER_NAME_FIREEYE, INC.', 0.00019042654292998355)
# (u'EMPLOYER_NAME_YAHOO! INC.', 0.0001899483715890836)
# (u'EMPLOYER_NAME_UNIVERSITY OF CALIFORNIA, SAN DIEGO', 0.00018985870995067832)
# ('SOC_CODE_17-2081', 0.00018982581928522556)
# (u'EMPLOYER_NAME_CAPITAL ONE SERVICES, LLC', 0.00018932521482398058)
# (u'EMPLOYER_NAME_SAIBERSYS INC', 0.0001891113348084068)
# (u'EMPLOYER_NAME_NETAPP, INC.', 0.0001885390740696418)
# (u'EMPLOYER_NAME_SOFTPATH SYSTEMS INC', 0.00018785737838900507)
# (u'EMPLOYER_NAME_PARTNERS HEALTHCARE', 0.00018775826485494982)
# ('SOC_CODE_43-4051', 0.0001877265920694201)
# (u'EMPLOYER_NAME_STRATEGISM INC.', 0.00018679745733076293)
# (u'EMPLOYER_NAME_ESYSTEMS, INC.', 0.00018662810395672492)
# (u'EMPLOYER_NAME_TRANS AMERICAN INFORMATION SYSTEMS INC', 0.00018619387606185064)
# (u'EMPLOYER_NAME_PARAM HEALTHCARE & IT SERVICES, INC', 0.00018576307583101855)
# (u'EMPLOYER_NAME_DELL USA L.P.', 0.00018564446816247667)
# (u'EMPLOYER_NAME_NAVITAS BUSINESS CONSULTING INC', 0.00018511827038655767)
# (u'EMPLOYER_NAME_PRIME THERAPEUTICS, LLC', 0.00018479700307621493)
# (u'EMPLOYER_NAME_INHERENT TECHNOLOGIES, LLC', 0.00018380223444042917)
# (u'EMPLOYER_NAME_UNIVERSITY OF WISCONSIN-MADISON', 0.00018355657420064057)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF VERMONT', 0.00018317678641856035)
# (u'EMPLOYER_NAME_SYNCHRONISYS, INC.', 0.00018279575861061253)
# (u'EMPLOYER_NAME_DRIVESTREAM, INC.', 0.0001827056083616303)
# (u'EMPLOYER_NAME_MY SUPPLY CHAIN GROUP, LLC', 0.00018263648684312312)
# (u'EMPLOYER_NAME_THE FOUNTAIN GROUP LLC', 0.00018246991946872362)
# (u'EMPLOYER_NAME_FACTSET RESEARCH SYSTEMS, INC.', 0.00018235324715931825)
# (u'EMPLOYER_NAME_BRILLIO, LLC', 0.00018229380861490592)
# (u'EMPLOYER_NAME_EBS HEALTHCARE, INC.', 0.0001818208494427625)
# (u'EMPLOYER_NAME_UNIVERSITY OF CALIFORNIA AT SANTA BARBARA', 0.00018164279221563688)
# (u'EMPLOYER_NAME_HENRY FORD HEALTH SYSTEM', 0.00018143937701792343)
# (u'EMPLOYER_NAME_HOWARD HUGHES MEDICAL INSTITUTE', 0.00018132939124161166)
# (u'EMPLOYER_NAME_TRANSAMERICA LIFE INSURANCE COMPANY', 0.00018112013806260765)
# (u'EMPLOYER_NAME_RELIANT VISION GROUP INC', 0.00018009338027182446)
# (u'EMPLOYER_NAME_PERSISTENT SYSTEMS, INC.', 0.0001800883472091781)
# (u'EMPLOYER_NAME_LIBSYS INC', 0.00017976856295888967)
# (u'EMPLOYER_NAME_CITIZENS FINANCIAL GROUP, INC.', 0.00017966172207258514)
# (u'EMPLOYER_NAME_A2Z DEVELOPMENT CENTER, INC.', 0.00017964147285783706)
# (u'EMPLOYER_NAME_FIDELITY TECHNOLOGY GROUP LLC', 0.0001796110666747664)
# (u'EMPLOYER_NAME_AMAZON WEB SERVICES, INC.', 0.0001794750334680553)
# (u'EMPLOYER_NAME_INFOR (US), INC.', 0.0001793729155729812)
# ('SOC_CODE_19-1013', 0.00017903221431509955)
# (u'EMPLOYER_NAME_AGC NETWORKS, INC.', 0.00017838444717839476)
# (u'EMPLOYER_NAME_TRINITY PARTNERS, LLC', 0.0001783116755090136)
# (u'EMPLOYER_NAME_ORCHESTRA TECHNOLOGY, INC', 0.00017823449542918267)
# (u'EMPLOYER_NAME_ERNST &AMP; YOUNG U.S. LLP', 0.00017812892154233693)
# (u'EMPLOYER_NAME_CSC COVANSYS CORPORATION', 0.00017781910568696107)
# ('SOC_CODE_27-1024', 0.00017776263587609625)
# (u'EMPLOYER_NAME_TEMPLE UNIVERSITY--A COMMONWEALTH UNIVERSITY', 0.00017770804790943342)
# (u'EMPLOYER_NAME_HALLIBURTON ENERGY SERVICES, INC.', 0.00017766643602457687)
# (u'EMPLOYER_NAME_ICAHN SCHOOL OF MEDICINE AT MOUNT SINAI', 0.0001766596630620216)
# (u'EMPLOYER_NAME_KEY BUSINESS SOLUTIONS, INC', 0.00017658091293151293)
# (u'EMPLOYER_NAME_BATTELLE', 0.00017625228550784033)
# (u'EMPLOYER_NAME_VISIONET SYSTEMS, INC.', 0.00017601450930741045)
# (u'EMPLOYER_NAME_BETH ISRAEL DEACONESS MEDICAL CENTER, INC.', 0.0001749075769966447)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF MONTANA', 0.00017480678112126962)
# (u'EMPLOYER_NAME_VISA TECHNOLOGY & OPERATIONS LLC', 0.0001746887107708688)
# (u'EMPLOYER_NAME_INSPIRAGE LLC', 0.00017456253133232106)
# ('SOC_CODE_11-9039', 0.00017417238730905006)
# (u'EMPLOYER_NAME_CONSULT AMERICA INC', 0.0001736968825785668)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF IOWA', 0.000173690228939546)
# (u'EMPLOYER_NAME_NOVISYNC, INC.', 0.00017322188926663655)
# (u'EMPLOYER_NAME_LHP SOFTWARE, LLC', 0.000172663563251148)
# (u'EMPLOYER_NAME_ADEPTPROS, INC.', 0.00017138186846063624)
# (u'EMPLOYER_NAME_CVS RX SERVICES, INC.', 0.00017099264610953983)
# (u'EMPLOYER_NAME_GRAVITY5LLC', 0.0001709712746214787)
# (u'EMPLOYER_NAME_ABB INC.', 0.00017085635629469865)
# (u'EMPLOYER_NAME_RAPIDIT INC.', 0.00017066372738267838)
# (u'EMPLOYER_NAME_KEYSTONE LOGIC INC.', 0.00017032911717291708)
# (u'EMPLOYER_NAME_UNIVERSITY OF TEXAS RIO GRANDE VALLEY', 0.00017026647029116617)
# (u'EMPLOYER_NAME_PYRAMID TECHNOLOGY SOLUTIONS, INC', 0.0001702651866117766)
# ('SOC_CODE_13-1011', 0.00016997719005540588)
# (u'EMPLOYER_NAME_REHABCARE GROUP EAST, INC.', 0.00016994860271020917)
# (u"EMPLOYER_NAME_ST. LUKE'S-ROOSEVELT HOSPITAL CENTER", 0.00016956782915560195)
# (u'EMPLOYER_NAME_ARIZONA STATE UNIVERSITY', 0.00016899888013437498)
# (u'EMPLOYER_NAME_TECHORBIT INC', 0.00016885891811627615)
# (u'EMPLOYER_NAME_APPLIED MATERIALS, INC.', 0.00016875837634535275)
# (u'EMPLOYER_NAME_CGI TECHNOLOGIES AND SOLUTIONS INC.', 0.00016846817813206562)
# (u'EMPLOYER_NAME_LOGITECHNICA LLC', 0.00016812519075709754)
# (u'EMPLOYER_NAME_SAMSUNG ELECTRONICS AMERICA, INC.', 0.00016764143360636105)
# (u'EMPLOYER_NAME_INDIANA UNIVERSITY', 0.00016746300017592288)
# (u'EMPLOYER_NAME_OHIO PUBLIC EMPLOYEES RETIREMENT SYSTEM', 0.00016704410349336842)
# (u'EMPLOYER_NAME_HORIZONSOFTSOLUTIONS, INC', 0.00016666334971023904)
# (u'EMPLOYER_NAME_THE ADVISORY BOARD COMPANY', 0.00016642518261282243)
# (u'EMPLOYER_NAME_CONTINENTAL AUTOMOTIVE SYSTEMS, INC.', 0.0001663700768089131)
# (u'EMPLOYER_NAME_LEAD IT CORPORATION', 0.00016603117490330825)
# (u'EMPLOYER_NAME_DETROIT ENGINEERED PRODUCTS, INC.', 0.00016600906985157857)
# (u'EMPLOYER_NAME_IDEXCEL, INC.', 0.00016574105300569807)
# ('SOC_CODE_17-2074', 0.0001641049253462415)
# (u'EMPLOYER_NAME_GENESIS ELDERCARE REHABILITATION SERVICES, LLC', 0.00016399020286441307)
# ('SOC_CODE_13-2031', 0.00016383661493346772)
# (u'EMPLOYER_NAME_GENERAL MOTORS COMPANY', 0.00016376239588921477)
# (u'EMPLOYER_NAME_ECOM CONSULTING INC', 0.000163676325690944)
# (u'EMPLOYER_NAME_THE DINEX GROUP, LLC', 0.00016318149528267453)
# (u'EMPLOYER_NAME_UNIVERSITY OF COLORADO', 0.0001627687489919904)
# (u'EMPLOYER_NAME_RUSH UNIVERSITY MEDICAL CENTER', 0.00016236253918484197)
# (u'EMPLOYER_NAME_VEDICSOFT SOLUTIONS LLC', 0.00016228146605189232)
# (u'EMPLOYER_NAME_REDEEMSOFT, LLC', 0.00016195655868150275)
# (u'EMPLOYER_NAME_CITIUSTECH INC', 0.00016191861820203892)
# (u'EMPLOYER_NAME_ST. BARNABAS HOSPITAL', 0.00016157518801533408)
# (u'EMPLOYER_NAME_COMPUTER SCIENCES CORPORATION', 0.00016149645687850843)
# (u'EMPLOYER_NAME_IGT', 0.00016144280667698655)
# ('SOC_CODE_11-9032', 0.00016101290357706095)
# (u'EMPLOYER_NAME_ITECH ANALYST CORP', 0.00016092741152362738)
# (u'EMPLOYER_NAME_UNIVERSITY OF MARYLAND, BALTIMORE', 0.0001607497837267351)
# (u'EMPLOYER_NAME_AGCO CORPORATION', 0.0001606792953655135)
# ('SOC_CODE_17-2111', 0.0001604653807535096)
# (u'EMPLOYER_NAME_GOLDMAN SACHS BANK USA', 0.0001602307920836189)
# (u'EMPLOYER_NAME_INFOBLOX INC.', 0.00015983144867615125)
# (u'EMPLOYER_NAME_INTERFACE REHAB INC.', 0.00015965673867577508)
# (u'EMPLOYER_NAME_ZIONE SOLUTIONS, LLC.', 0.00015938658445038148)
# (u'EMPLOYER_NAME_CATERPILLAR INC.', 0.00015907583299359313)
# (u'EMPLOYER_NAME_THE VERITAS HEALTHCARE SOLUTIONS LLC', 0.00015864034485441666)
# (u'EMPLOYER_NAME_INDO WELSH COMPANY, INC.', 0.00015863074503323795)
# ('SOC_CODE_15-1034', 0.00015816630691420637)
# (u'EMPLOYER_NAME_SIGILINFOTECH INC', 0.00015811656444030052)
# (u'EMPLOYER_NAME_FEDERAL HOME LOAN MORTGAGE CO.', 0.00015777682792954498)
# (u'EMPLOYER_NAME_EQUIFAX INC.', 0.0001577276634757923)
# (u'EMPLOYER_NAME_HARMAN CONNECTED SERVICES, INC.', 0.00015770142105506885)
# (u'EMPLOYER_NAME_IMPERIO INC', 0.00015741081082771373)
# (u'EMPLOYER_NAME_LAM RESEARCH CORPORATION', 0.00015731424749786905)
# (u'EMPLOYER_NAME_AMERICAN UNIVERSITY', 0.0001573123225205168)
# (u'EMPLOYER_NAME_PRIME HEALTHCARE MANAGEMENT, INC.', 0.00015728488212532894)
# (u'EMPLOYER_NAME_XAVIENT INFORMATION SYSTEMS, INC.', 0.00015716547804276807)
# (u'EMPLOYER_NAME_UNIVERSITY OF ARKANSAS FOR MEDICAL SCIENCES', 0.0001570565884196872)
# (u'EMPLOYER_NAME_INOVANT, LLC', 0.0001567884341244304)
# (u'EMPLOYER_NAME_HP ENTERPRISE SERVICES, LLC', 0.000156544288965031)
# (u'EMPLOYER_NAME_PIONEER CONSULTING SERVICES LLC', 0.0001564758072554612)
# ('SOC_CODE_27-2022', 0.00015633811447092575)
# (u'EMPLOYER_NAME_S9 TECHNOLOGIES INC', 0.0001559150501436509)
# ('SOC_CODE_29-1141', 0.00015590662551966347)
# (u'EMPLOYER_NAME_DENVER PUBLIC SCHOOLS DISTRICT 1', 0.0001556992006332468)
# (u'EMPLOYER_NAME_SAP AMERICA, INC.', 0.0001556471648484682)
# (u'EMPLOYER_NAME_THE PRUDENTIAL INSURANCE COMPANY OF AMERICA', 0.00015507440070218335)
# (u'EMPLOYER_NAME_SUPERNOVA INFOTECHNOLOGIES, INC', 0.00015495479915533575)
# (u'EMPLOYER_NAME_AESOP USA, INC.', 0.0001549177333920052)
# (u'EMPLOYER_NAME_TECHMILEAGE, LLC', 0.00015481647380656804)
# (u'EMPLOYER_NAME_DANA-FARBER CANCER INSTITUTE', 0.00015455747338540373)
# (u'EMPLOYER_NAME_BARCLAYS SERVICES CORP.', 0.00015454575126737607)
# (u'EMPLOYER_NAME_ENGINEERING TECHNOLOGY ASSOCIATES, INC.', 0.00015388590777472877)
# (u'EMPLOYER_NAME_GLOBAL IT INC', 0.00015386160220352382)
# (u'EMPLOYER_NAME_HOSPIRA INC., A PFIZER COMPANY', 0.00015373637687425041)
# (u'EMPLOYER_NAME_FIDELITY BROKERAGE SERVICES LLC', 0.0001536684702982475)
# ('SOC_CODE_25-1022', 0.0001534377533409427)
# (u'EMPLOYER_NAME_BLOOMBERG, LP', 0.0001533682579507967)
# (u'EMPLOYER_NAME_PARSONS BRINCKERHOFF, INC.', 0.00015328710384759632)
# (u'EMPLOYER_NAME_SUTTER HEALTH', 0.0001530145473012323)
# (u'EMPLOYER_NAME_R3 TECHNOLOGY INC', 0.0001529131387027696)
# (u'EMPLOYER_NAME_MICHIGAN TECHNOLOGY GROUP INC', 0.0001528044562280859)
# (u'EMPLOYER_NAME_QCENTRIO, INC', 0.00015265979762950436)
# (u'EMPLOYER_NAME_BAHA INDUSTRIES CORP.', 0.00015259799597719685)
# (u'EMPLOYER_NAME_MAINSTREAMTEK CORPORATION', 0.00015247867549769963)
# (u'EMPLOYER_NAME_GENESIS ELDERCARE REHABILITATION SERVICES, INC.', 0.0001524136512813077)
# (u'EMPLOYER_NAME_LANCESOFT, INC.', 0.00015238534165578518)
# (u'EMPLOYER_NAME_MISSISSIPPI STATE UNIVERSITY', 0.00015232418781206588)
# (u'EMPLOYER_NAME_IPSOFT INCORPORATED', 0.0001518929845402662)
# (u'EMPLOYER_NAME_SIEMENS PLM SOFTWARE, INC.', 0.00015182692554036308)
# (u'EMPLOYER_NAME_EXPEDIENT CONSULTING SERVICES INC.', 0.00015179316775941823)
# (u'EMPLOYER_NAME_PROSOFT IT SERVICES, INC', 0.00015156503655295334)
# (u'EMPLOYER_NAME_NASSCOMM, INC.', 0.00015150614110553894)
# (u'EMPLOYER_NAME_HORTONWORKS, INC', 0.00015129083705879258)
# (u'EMPLOYER_NAME_STERLING 5, INC.', 0.0001512848656225416)
# (u'EMPLOYER_NAME_BLACKROCK CAPITAL MANAGEMENT, INC.', 0.00015115943958055004)
# (u'EMPLOYER_NAME_TERADATA OPERATIONS, INC.', 0.00015104991903198452)
# (u'EMPLOYER_NAME_TECH MAHINDRA (AMERICAS), INC.', 0.00015102418888544885)
# ('SOC_CODE_11-9033', 0.0001509027728659893)
# (u'EMPLOYER_NAME_SHUBH SOLUTIONS LLC', 0.00015082772612322808)
# (u'EMPLOYER_NAME_DATAWIZ CORPORATION', 0.00015069431504063046)
# ('SOC_CODE_25-1063', 0.000150438135240006)
# (u'EMPLOYER_NAME_A10 NETWORKS, INC.', 0.00014963377122264926)
# (u'EMPLOYER_NAME_TENAZX INC.', 0.00014925631938809245)
# (u'EMPLOYER_NAME_HEWLETT-PACKARD STATE & LOCAL ENTERPRISE SERVICES, INC.', 0.00014915104105503788)
# (u'EMPLOYER_NAME_GLOBALFOUNDRIES U.S. INC.', 0.00014904692255186423)
# (u'EMPLOYER_NAME_LIFE TECHNOLOGIES CORPORATION', 0.00014902556141135434)
# (u'EMPLOYER_NAME_MASSACHUSETTS EYE AND EAR INFIRMARY', 0.00014901881894516624)
# (u'EMPLOYER_NAME_KASTECH SOLUTIONS LLC', 0.00014887266305045195)
# (u'EMPLOYER_NAME_RITE AID CORP.', 0.0001487215890417715)
# (u'EMPLOYER_NAME_AMERICAN EXPRESS COMPANY', 0.00014869592063107356)
# (u'EMPLOYER_NAME_KASHIV PHARMA LLC', 0.00014869089049320786)
# (u'EMPLOYER_NAME_REGIONS FINANCIAL CORPORATION', 0.00014868123934779455)
# (u'EMPLOYER_NAME_QUALCOMM INCORPORATED', 0.00014857571044137445)
# (u'EMPLOYER_NAME_ANAGH TECHNOLOGIES INC.', 0.000148475746347932)
# (u'EMPLOYER_NAME_EASI LLC', 0.00014828894459098353)
# (u'EMPLOYER_NAME_MYZEAL IT SOLUTIONS LLC', 0.0001480049889291016)
# (u'EMPLOYER_NAME_HP INC.', 0.00014793053591663247)
# (u'EMPLOYER_NAME_OPTICSPLANET INC.', 0.00014766010178275064)
# (u'EMPLOYER_NAME_KBTS TECHNOLOGIES, INC.', 0.0001476397673551651)
# (u'EMPLOYER_NAME_SANFORD CLINIC NORTH', 0.000147534065113057)
# (u'EMPLOYER_NAME_PRUDENT TECHNOLOGIES & CONSULTING, INC.', 0.0001469016266216374)
# (u'EMPLOYER_NAME_PEK SYSTEMS INC', 0.0001468407895846984)
# (u'EMPLOYER_NAME_WHIRLPOOL CORPORATION', 0.00014635318896568053)
# (u'EMPLOYER_NAME_UCRYA LLC', 0.00014633298737664932)
# (u'EMPLOYER_NAME_WRIGHT CENTER FOR GRADUATE MEDICAL EDUCATION', 0.00014611573537637944)
# (u'EMPLOYER_NAME_FIS MANAGEMENT SERVICES, LLC', 0.00014610338033787816)
# (u'EMPLOYER_NAME_HUMANA INC.', 0.00014605832084128154)
# (u'EMPLOYER_NAME_MR BUSINESS CORPORATION', 0.00014604927491070383)
# ('SOC_CODE_27-1021', 0.00014593484747413117)
# ('SOC_CODE_19-1022', 0.0001458543604261539)
# (u'EMPLOYER_NAME_SOFTWARE PARADIGMS INTERNATIONAL GROUP, LLC', 0.00014578286506357804)
# (u'EMPLOYER_NAME_TUSIMPLE', 0.00014570619877673813)
# (u'EMPLOYER_NAME_THE TRUSTEES OF PRINCETON UNIVERSITY', 0.00014565121778922888)
# (u'EMPLOYER_NAME_XAD, INC.', 0.00014549903106974757)
# (u'EMPLOYER_NAME_ORACLE AMERICA, INC', 0.00014548019248225057)
# (u'EMPLOYER_NAME_PRADON TECHNOLOGIES LLC', 0.00014528759063480955)
# (u'EMPLOYER_NAME_STANDARD CHARTERED BANK', 0.00014516385754691777)
# (u'EMPLOYER_NAME_XILINX, INC.', 0.00014503093825696898)
# (u'EMPLOYER_NAME_DIVENSI INC.', 0.00014500134598348832)
# (u'EMPLOYER_NAME_UNIVERSITY OF ARKANSAS', 0.0001449917339921673)
# ('SOC_CODE_25-1124', 0.00014479515867832663)
# (u'EMPLOYER_NAME_JOHNSON CONTROLS, INC.', 0.00014461843557810232)
# (u'EMPLOYER_NAME_MONTEFIORE MEDICAL CENTER', 0.00014454936810049946)
# (u'EMPLOYER_NAME_AXIOS INTERNATIONAL INC.', 0.00014420219423248707)
# (u'EMPLOYER_NAME_UNIVERSITY OF VIRGINIA', 0.00014371605971636977)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF TEXAS AT AUSTIN', 0.00014355090450179212)
# (u'EMPLOYER_NAME_YASH TECHNOLOGIES, INC.', 0.00014331966022024557)
# (u'EMPLOYER_NAME_E-EMPHASYS TECHNOLOGIES INC', 0.00014286021514230677)
# (u'EMPLOYER_NAME_RIVERBED TECHNOLOGY, INC.', 0.00014283510057200156)
# (u'EMPLOYER_NAME_EXPEDITORS INTERNATIONAL OF WASHINGTON, INC.', 0.00014275518209732596)
# (u'EMPLOYER_NAME_POLARIS CONSULTING & SERVICES LTD', 0.00014256734027528537)
# (u'EMPLOYER_NAME_ACXIOM CORPORATION', 0.00014255876210720998)
# (u'EMPLOYER_NAME_HSBC BANK USA, N.A.', 0.00014239383372058933)
# ('SOC_CODE_11-2031', 0.00014236421163712194)
# (u'EMPLOYER_NAME_TRUSTEES OF BOSTON UNIVERSITY', 0.00014210908525143047)
# (u'EMPLOYER_NAME_AUTODESK, INC.', 0.0001419779499100249)
# (u'EMPLOYER_NAME_INFOMATICS CORP', 0.00014197251327457446)
# (u'EMPLOYER_NAME_UST GLOBAL INC', 0.00014171792085336142)
# (u'EMPLOYER_NAME_TEXAS A&M UNIVERSITY', 0.00014168730067428293)
# (u'EMPLOYER_NAME_NICIRA, INC.', 0.00014154288855111608)
# (u'EMPLOYER_NAME_ARICENT N.A. INC.', 0.0001414533923269469)
# (u'EMPLOYER_NAME_MR INFO TECH LLC.', 0.00014089369466777085)
# (u'EMPLOYER_NAME_TEKSYSTEMS GLOBAL SERVICES LLC', 0.00014084175124140443)
# (u'EMPLOYER_NAME_MASTECH, INC., A MASTECH HOLDINGS, INC. COMPANY', 0.00014072609900706658)
# (u'EMPLOYER_NAME_DRISHTICON INC.', 0.00014054031710881296)
# (u'EMPLOYER_NAME_CORE PROVIDERS LLC', 0.00014026010923410618)
# (u'EMPLOYER_NAME_EVEREST CONSULTING GROUP, INC.,', 0.00014024368055651562)
# (u'EMPLOYER_NAME_HONEYWELL INTERNATIONAL INC.', 0.0001398309258970145)
# (u'EMPLOYER_NAME_CHARTER GLOBAL, INC.', 0.0001395528349750617)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF TENNESSEE', 0.00013917734887225605)
# (u'EMPLOYER_NAME_ENTERPRISE MOBILITY INC', 0.00013917199461828145)
# (u'EMPLOYER_NAME_EDISQUARE INC.', 0.00013859984350909235)
# (u'EMPLOYER_NAME_BEST BUY ENTERPRISE SERVICES, INC.', 0.0001383563817857977)
# (u'EMPLOYER_NAME_ARGUS MERCHANT SERVICES LLC', 0.00013834035538975726)
# (u'EMPLOYER_NAME_AURITAS LLC', 0.00013824400319937497)
# (u'EMPLOYER_NAME_LENOVO (UNITED STATES) INC.', 0.00013815247484388977)
# (u'EMPLOYER_NAME_DAS GEMACHT, INC.', 0.0001380665967146885)
# (u'EMPLOYER_NAME_UNIVERSITY OF MASSACHUSETTS BOSTON', 0.0001380005160899583)
# ('SOC_CODE_25-1066', 0.00013768737063140786)
# (u'EMPLOYER_NAME_WHITERIVER UNIFIED SCHOOL DISTRICT', 0.00013743513518800216)
# (u'EMPLOYER_NAME_CONCERT TECH CORPORATION', 0.00013733510980471308)
# (u'EMPLOYER_NAME_HUMANA INSURANCE COMPANY', 0.00013725827354782192)
# (u'EMPLOYER_NAME_BIRLASOFT INC', 0.00013718894524396175)
# (u'EMPLOYER_NAME_SOFTWARE TRANSFORMATIONS INC', 0.0001371813904007552)
# (u'EMPLOYER_NAME_TEXARA SOLUTIONS LLC', 0.00013660664414374228)
# (u'EMPLOYER_NAME_SBP CONSULTING INC.', 0.0001359955120398621)
# (u'EMPLOYER_NAME_SKML, LLC', 0.0001359899984931323)
# (u'EMPLOYER_NAME_SYNECHRON, INC.', 0.00013598048508654145)
# (u'EMPLOYER_NAME_LPL FINANCIAL LLC', 0.00013588478379404018)
# (u'EMPLOYER_NAME_PICA9, INC.', 0.0001356747203837182)
# (u'EMPLOYER_NAME_SIEMENS PLM SOFTWARE INC.', 0.0001356154691493414)
# (u'EMPLOYER_NAME_MARVEL TECHNOLOGIES INC', 0.00013539276864665072)
# (u'EMPLOYER_NAME_MORGAN STANLEY & CO LLC', 0.00013535171766126288)
# ('SOC_CODE_15-1035', 0.00013533241068845435)
# (u'EMPLOYER_NAME_UNIVERSITY OF CALIFORNIA, BERKELEY', 0.00013531040534661397)
# (u'EMPLOYER_NAME_BLUE CLOUD TECHS CORP', 0.00013526045410852872)
# (u'EMPLOYER_NAME_ANDERSEN CORPORATION', 0.00013515168800451666)
# (u'EMPLOYER_NAME_NCR CORPORATION', 0.00013510722079435028)
# (u'EMPLOYER_NAME_IQ SPECTRA INC', 0.00013504876833369685)
# (u'EMPLOYER_NAME_VSV SYSTEMS CORPORATION', 0.00013504744451203887)
# (u'EMPLOYER_NAME_NEW YORK UNIVERSITY', 0.00013498893998837523)
# (u'EMPLOYER_NAME_PIORION SOLUTIONS INC', 0.00013498553204695866)
# ('SOC_CODE_19-1099', 0.00013478724610616687)
# (u'EMPLOYER_NAME_UNITED AIRLINES, INC.', 0.00013447211952216821)
# (u'EMPLOYER_NAME_QVERGE LLC', 0.00013425858606946436)
# (u'EMPLOYER_NAME_UNIVERSITY OF CINCINNATI', 0.00013420556799731434)
# ('SOC_CODE_19-1041', 0.00013412936559023612)
# ('SOC_CODE_29-1127', 0.0001335220934399514)
# ('SOC_CODE_13-1141', 0.00013342764992803956)
# (u'EMPLOYER_NAME_PROFICIENT BUSINESS SYSTEMS, INC.', 0.00013336775814998015)
# (u'EMPLOYER_NAME_OPEG INC', 0.00013303307229941652)
# (u'EMPLOYER_NAME_ISAAC GROUP, LLC', 0.00013288952468136972)
# (u'EMPLOYER_NAME_MACYS.COM, LLC', 0.0001328849598057499)
# (u'EMPLOYER_NAME_INTALENT LLC', 0.0001328765690892965)
# (u'EMPLOYER_NAME_WAVE SOLUTIONS INC.', 0.00013272376503174985)
# (u'EMPLOYER_NAME_ARIBA, INC.', 0.00013272193259988694)
# (u'EMPLOYER_NAME_TUFTS UNIVERSITY', 0.00013228673315608889)
# (u'EMPLOYER_NAME_JETBLUE AIRWAYS', 0.00013215450634012615)
# (u'EMPLOYER_NAME_FUJITSU AMERICA, INC.', 0.00013202617273372707)
# (u'EMPLOYER_NAME_RYZEN SOLUTIONS', 0.00013199201803680715)
# (u'EMPLOYER_NAME_OSLO SOLUTIONS LLC', 0.00013191384547142174)
# ('SOC_CODE_17-2144', 0.00013184776244727598)
# (u'EMPLOYER_NAME_GENERAL ELECTRIC COMPANY', 0.0001310650877172409)
# ('SOC_CODE_29-2052', 0.00013101999041475833)
# (u'EMPLOYER_NAME_ST. LOUIS LANGUAGE IMMERSION SCHOOLS, INC.', 0.00013091261753479073)
# ('SOC_CODE_13-2052', 0.00013089381964171803)
# (u'EMPLOYER_NAME_MARQUETTE UNIVERSITY', 0.00013079253582278972)
# (u'EMPLOYER_NAME_ADECCO GROUP NA/MODIS, INC.', 0.00013070512879090625)
# (u'EMPLOYER_NAME_UNIVERSITY OF MISSISSIPPI MEDICAL CENTER', 0.00013058966062518573)
# (u'EMPLOYER_NAME_LOGIC INFORMATION SYSTEMS, INC.', 0.00013057827161696471)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF TEXAS AT DALLAS', 0.00013046534712181308)
# (u'EMPLOYER_NAME_GUIDEWIRE SOFTWARE INC.', 0.00013026122146384363)
# (u'EMPLOYER_NAME_IT SPIN INC', 0.00012936780195677364)
# (u'EMPLOYER_NAME_KNOWLEDGE BUILDERS, INC.', 0.00012933565320614635)
# (u'EMPLOYER_NAME_MOTOROLA MOBILITY LLC', 0.00012923402968545165)
# (u'EMPLOYER_NAME_GUIDEWIRE SOFTWARE, INC.', 0.00012912653392705862)
# (u'EMPLOYER_NAME_TEXAS INSTRUMENTS INCORPORATED', 0.00012850279435658505)
# (u'EMPLOYER_NAME_GEORGIA STATE UNIVERSITY', 0.0001283737009552867)
# (u'EMPLOYER_NAME_STELLAR SERVICES, INC', 0.00012812505888388134)
# (u'EMPLOYER_NAME_ALBERT EINSTEIN COLLEGE OF MEDICINE, INC.', 0.00012803925174498704)
# (u'EMPLOYER_NAME_84.51 LLC', 0.00012793073391346348)
# (u'EMPLOYER_NAME_SAATCHI & SAATCHI NORTH AMERICA, INC.', 0.00012776530266378266)
# (u'EMPLOYER_NAME_BRAINER CONSULTANCY, INC', 0.00012758031801063746)
# ('SOC_CODE_25-1021', 0.00012742275533495653)
# (u'EMPLOYER_NAME_INFODAT INTERNATIONAL INC', 0.00012718884765841406)
# ('SOC_CODE_19-1012', 0.00012702260693911774)
# (u'EMPLOYER_NAME_SIEMENS ENERGY, INC.', 0.00012699724470267647)
# (u'EMPLOYER_NAME_YOUNGSOFT INC.', 0.00012687620448245747)
# (u'EMPLOYER_NAME_VANDERBILT UNIVERSITY', 0.000126627270339599)
# (u'EMPLOYER_NAME_CALIFORNIA INSTITUTE OF TECHNOLOGY', 0.0001264236025373174)
# (u'EMPLOYER_NAME_UNIVERSITY OF MINNESOTA', 0.0001262898048347914)
# ('SOC_CODE_25-1125', 0.00012618637793985406)
# (u'EMPLOYER_NAME_TEXAS A&M AGRILIFE RESEARCH', 0.00012613417549413094)
# (u'EMPLOYER_NAME_PARSOFT LLC', 0.00012593529750747458)
# (u'EMPLOYER_NAME_COGNILYTICS, INC.', 0.00012585555893860197)
# (u'EMPLOYER_NAME_I3GLOBALTECH INC', 0.0001257797698569932)
# (u'EMPLOYER_NAME_SNAP INC.', 0.00012577865097233666)
# (u'EMPLOYER_NAME_FLEXTRADE SYSTEMS INC', 0.00012573807235316317)
# (u'EMPLOYER_NAME_IT CATS, LLC', 0.00012555339190518453)
# (u'EMPLOYER_NAME_BOX, INC.', 0.00012552512082307068)
# (u'EMPLOYER_NAME_ANJANEYAP, INC.', 0.00012551395745917962)
# (u'EMPLOYER_NAME_VECTORSOFT LLC', 0.00012540607780404313)
# ('SOC_CODE_25-3099', 0.00012528590425518168)
# (u'EMPLOYER_NAME_GLOBAL BRIDGE INFOTECH INC,.', 0.00012519678461461208)
# ('SOC_CODE_11-3121', 0.00012471609129890003)
# (u'EMPLOYER_NAME_PHYSICIAN AFFILIATE GROUP OF NEW YORK, P.C.', 0.0001245995493609377)
# (u'EMPLOYER_NAME_SMITHSONIAN ASTROPHYSICAL OBSERVATORY', 0.00012449043819641855)
# (u'EMPLOYER_NAME_INDEPENDENT LIVING SYSTEMS, LLC', 0.0001244209326679953)
# (u'EMPLOYER_NAME_QAD INC.', 0.0001242591828392555)
# (u'EMPLOYER_NAME_NOKIA SOLUTIONS AND NETWORKS US LLC', 0.0001241524220987496)
# (u'EMPLOYER_NAME_E-DATA EXPERTS INC', 0.00012396795008822175)
# (u'EMPLOYER_NAME_ALPHA SYNOPSYS INC', 0.00012387097822924643)
# ('SOC_CODE_29-9011', 0.00012372304517462577)
# (u'EMPLOYER_NAME_UNIVERSITY OF SOUTH DAKOTA', 0.0001234405816590222)
# (u'EMPLOYER_NAME_VLINK,  INC.', 0.00012341541607932286)
# (u'EMPLOYER_NAME_HEXAWARE TECHNOLOGIES, INC.', 0.00012336914017696538)
# (u'EMPLOYER_NAME_DLIFLC - DEFENSE LANGUAGE INSTITUTE FOREIGH LANGUAGE CENTER', 0.00012316117254559093)
# (u'EMPLOYER_NAME_UNIVERSITY OF ILLINOIS', 0.00012312520408814856)
# (u'EMPLOYER_NAME_YALE UNIVERSITY', 0.00012289593069199624)
# (u'EMPLOYER_NAME_COPART, INC.', 0.00012289456284941106)
# (u'EMPLOYER_NAME_INNIVE INC', 0.00012288378600268772)
# (u'EMPLOYER_NAME_SHIRE HUMAN GENETIC THERAPIES INC.', 0.00012267892589401432)
# ('SOC_CODE_27-4032', 0.00012261995947359178)
# (u'EMPLOYER_NAME_AMERICAN AIRLINES, INC.', 0.0001225930515150675)
# (u'EMPLOYER_NAME_NUVASIVE, INC.', 0.00012258464991816656)
# (u'EMPLOYER_NAME_THE UNIVERSITY OF TENNESSEE, KNOXVILLE', 0.00012252677594852036)
# ('SOC_CODE_19-4041', 0.000122508256868773)
# (u'EMPLOYER_NAME_GENUINEIT LLC', 0.00012239840247710686)
# (u'EMPLOYER_NAME_INTELLECT BUSINESS SOLUTIONS, LLC', 0.0001220960401773306)
# (u'EMPLOYER_NAME_AVAYA INC.', 0.00012208079865158594)
# (u'EMPLOYER_NAME_IBLESOFT INC,DUNS#791327054', 0.00012202831809281589)
# (u'EMPLOYER_NAME_HIGHBROW BUSINESS SOLUTIONS LLC', 0.00012200982989090828)
# (u'EMPLOYER_NAME_AOL INC.', 0.00012194105058599433)
# (u'EMPLOYER_NAME_STUBHUB, INC.', 0.00012182176597683159)
# (u'EMPLOYER_NAME_SEAGATE US LLC', 0.00012181813103641485)
# ('SOC_CODE_41-3099', 0.00012181360008499673)
# (u'EMPLOYER_NAME_HITACHI DATA SYSTEMS CORPORATION', 0.00012181164905631404)
# (u'EMPLOYER_NAME_MANHATTAN ASSOCIATES, INC.', 0.00012174726316852976)
# (u'EMPLOYER_NAME_NATIONAL FINANCIAL LLC', 0.000121595243454226)
# (u'EMPLOYER_NAME_COMPSULTING, LLC', 0.00012156459248298668)
# (u'EMPLOYER_NAME_CORECOMPETE LLC', 0.00012145752110705132)
# (u'EMPLOYER_NAME_ADVENT GLOBAL SOLUTIONS INC.', 0.00012143653650583739)
# ('SOC_CODE_23-1012', 0.00012140643684849001)
# (u'EMPLOYER_NAME_INDUS INC', 0.0001213159174055896)
# (u'EMPLOYER_NAME_WYE OAK HEALTHCARE OF HYATTSVILLE LLC', 0.00012106386186659177)
# (u'EMPLOYER_NAME_JNIT TECHNOLOGIES', 0.00012094137910827694)
# (u'EMPLOYER_NAME_TEAHLEAP SYSTEMS, INC', 0.00012087984275743586)
# (u'EMPLOYER_NAME_NGA GROUP INC', 0.00012086195306495029)
# (u'EMPLOYER_NAME_UNIVERSITY OF OKLAHOMA', 0.00012066464554148188)
# (u'EMPLOYER_NAME_CLOUD SOURCE, INC.', 0.00012054728100706539)
# (u'EMPLOYER_NAME_COMTEC CONSULTANTS, INC.', 0.00012053783172409034)
# (u'EMPLOYER_NAME_MAKEURCAREER LLC', 0.00012032901131638726)
# (u'EMPLOYER_NAME_CAPGEMINI AMERICA, INC. (LEGACY CAPGEMINI FINANCIAL SERVICES, INC.)', 0.00012030148797474473)
# (u'EMPLOYER_NAME_RESEARCH FOUNDATION OF CUNY', 0.00012028960777761455)
# (u'EMPLOYER_NAME_RESEARCH CORPORATION OF THE UNIVERSITY OF HAWAII', 0.00012020665471696656)
# (u'EMPLOYER_NAME_ESURANCE INSURANCE SERVICES, INC.', 0.00012006571145698426)
# (u'EMPLOYER_NAME_VSQUARE INFOTECH INC.', 0.00011996246031209363)
# (u'EMPLOYER_NAME_MICROEXCEL, INC', 0.00011983467500222412)
# (u'EMPLOYER_NAME_OATH HOLDINGS INC.', 0.00011974985786258798)
# (u'EMPLOYER_NAME_WELLS FARGO BANK, N.A.', 0.00011968733613313028)
# (u'EMPLOYER_NAME_SAVIN TECHNOLOGIES INC', 0.00011958555322995904)
# (u'EMPLOYER_NAME_RESOLVE TECH SOLUTIONS INC', 0.0001195701157593449)
# (u'EMPLOYER_NAME_ARTECH INFORMATION SYSTEMS LLC', 0.00011947962210978761)
# (u'EMPLOYER_NAME_THE NORTHERN TRUST COMPANY', 0.00011918171361634234)
# (u'EMPLOYER_NAME_ASPEN TECHNOLOGY, INC.', 0.00011917231842046433)
# (u'EMPLOYER_NAME_REAL SOFT, INC.', 0.000118786689003121)
# (u'EMPLOYER_NAME_R2 TECHNOLOGIES LLC', 0.00011877620502260872)
# (u'EMPLOYER_NAME_KPI PARTNERS, INC.', 0.0001187017132281528)
# (u'EMPLOYER_NAME_GOLDMAN, SACHS &AMP; CO.', 0.00011863670611076302)
# (u'EMPLOYER_NAME_ANJANEYAP, INC', 0.00011832051996287136)
# (u'EMPLOYER_NAME_OREGON STATE UNIVERSITY', 0.00011819985108068471)
# (u'EMPLOYER_NAME_CYBERSOURCE CORPORATION', 0.00011811603599318347)
# (u'EMPLOYER_NAME_UNIVERSITY OF SOUTH CAROLINA', 0.00011807935815993662)
# (u'EMPLOYER_NAME_SAGE IT, INC.', 0.00011796403146844051)
# (u'EMPLOYER_NAME_STANFORD HEALTH CARE', 0.00011790307265573618)
# (u'EMPLOYER_NAME_NUANCE COMMUNICATIONS, INC.', 0.00011790124721037037)
# (u'EMPLOYER_NAME_USA WASTE-MANAGEMENT RESOURCES, L.L.C.', 0.00011768431100999186)
# ('SOC_CODE_17-3022', 0.00011738813255558162)
# (u'EMPLOYER_NAME_DIXON HUGHES GOODMAN LLP', 0.00011714767457706736)
# (u'EMPLOYER_NAME_ITECH AMERICA INC', 0.00011702203261829684)
# (u'EMPLOYER_NAME_CAPITAL ONE, NATIONAL ASSOCIATION', 0.00011700000157363884)
# (u'EMPLOYER_NAME_THE UNCIA GROUP, INC', 0.00011699382414189108)
# (u'EMPLOYER_NAME_JOYALUKKAS JEWELRY TEXAS, INC.', 0.00011693097902078932)
# (u'EMPLOYER_NAME_GOOGLE, INC.', 0.00011692810360314535)
# (u'EMPLOYER_NAME_FLUOR ENTERPRISES, INC.', 0.00011681527573083547)
# (u'EMPLOYER_NAME_ITECH US, INC.', 0.0001167409731836025)
# (u'EMPLOYER_NAME_AMENSYS INC', 0.00011637846956025203)
# (u'EMPLOYER_NAME_MEDICAL UNIVERSITY OF SOUTH CAROLINA', 0.00011627473146246904)
# (u'EMPLOYER_NAME_TALENT9 INC', 0.00011614074108881871)
# (u'EMPLOYER_NAME_GFINET INC.', 0.00011599170230565419)
# (u'EMPLOYER_NAME_COMMUNITY REHABILITATION SERVICES INC', 0.00011576438078171687)
# (u'EMPLOYER_NAME_CERNER CORPORATION', 0.00011548251505306646)
# (u'EMPLOYER_NAME_CB TECHNOLOGY SERVICES CORPORATION', 0.0001153922106167067)
# (u'EMPLOYER_NAME_ANA-DATA CONSULTING INC', 0.00011502428606731551)
# (u'EMPLOYER_NAME_CHARLES SCHWAB AND COMPANY, INC.', 0.00011463251819832043)
# (u'EMPLOYER_NAME_PHOTON INFOTECH, INC.', 0.00011463184680775679)
# (u'EMPLOYER_NAME_COZY CONSULTING, LLC', 0.00011440262195085495)
# (u'EMPLOYER_NAME_AGAMA SOLUTIONS, INC.', 0.00011429147404866353)
# (u'EMPLOYER_NAME_TECHNOCONSULTING CORP', 0.0001142809957578596)
# ...
# (u'EMPLOYER_NAME_NEW YORK BLOOD CENTER', 1.8654702655642863e-05)
# (u'EMPLOYER_NAME_APPLIED MICRO CIRCUITS CORPORATION', 1.8654702655642863e-05)
# (u'EMPLOYER_NAME_180LA, LLC', 1.8654702655642863e-05)
# (u'EMPLOYER_NAME_TRIYARDS HOUSTON LLC', 1.8654702655642863e-05)
# (u'EMPLOYER_NAME_IMMIGRATION SOLUTIONS LLC', 1.8643735752259174e-05)
# (u'EMPLOYER_NAME_XALT ENERGY, LLC', 1.8640716523797195e-05)
# (u'EMPLOYER_NAME_LEGACY BUSINESS SOLUTION LLC', 1.8640716523797195e-05)
# (u'EMPLOYER_NAME_HUNTERDON CENTRAL REGIONAL HIGH SCHOOL', 1.856087470447134e-05)
# (u'EMPLOYER_NAME_ROSALIND FRANKLIN UNIVERSITY OF MEDICINE &AMP; SCIENCE', 1.853477177942295e-05)
# (u'EMPLOYER_NAME_KEANE, INC.', 1.848731026204509e-05)
# (u'EMPLOYER_NAME_ACUSHNET COMPANY', 1.848731026204509e-05)
# (u'EMPLOYER_NAME_MALONEBAILEY, LLP', 1.8451196808490305e-05)
# (u'EMPLOYER_NAME_RED CLAY CONSOLIDATED SCHOOL DISTRICT', 1.8407659936863635e-05)
# (u'EMPLOYER_NAME_HEARTLAND EMPLOYMENT SERVICES, LLC D/B/A', 1.8391175278601895e-05)
# (u'EMPLOYER_NAME_TECHNO-COMP INC', 1.8357118961573252e-05)
# (u'EMPLOYER_NAME_ASEC, INC.', 1.8348904582223398e-05)
# (u'EMPLOYER_NAME_WAYMO LLC', 1.8343693096786575e-05)
# (u'EMPLOYER_NAME_TRAACKR, INC.', 1.8327028241125956e-05)
# (u'EMPLOYER_NAME_ODYSSEY 2020 ACADEMY, INC.', 1.8316652668886234e-05)
# (u'EMPLOYER_NAME_RALLY HEALTH, INC.', 1.8316652668886234e-05)
# (u'EMPLOYER_NAME_1ST ORIENTAL MARKET, LLC', 1.8316652668886234e-05)
# (u'EMPLOYER_NAME_DSRK CONSULTING, INC.', 1.8316652668886234e-05)
# (u'EMPLOYER_NAME_YANFENG US AUTOMOTIVE INTERIOR SYSTEMS I LLC.', 1.8316652668886234e-05)
# (u'EMPLOYER_NAME_ROTELLA CAPITAL MANAGEMENT', 1.8316652668886234e-05)
# (u'EMPLOYER_NAME_EVEREST TECHNOLOGIES, INC.', 1.83118840976082e-05)
# (u'EMPLOYER_NAME_BMR HEALTH SERVICES, INC.', 1.822340425529912e-05)
# (u'EMPLOYER_NAME_ATLAS HEALTHCARE, LLC', 1.8101550471064762e-05)
# (u'EMPLOYER_NAME_LIFELINE SYSTEMS COMPANY', 1.8089408635774912e-05)
# (u'EMPLOYER_NAME_ROBERT A. UNDERHILL P.C.', 1.8085826574658864e-05)
# (u'EMPLOYER_NAME_IQLOGG, INC.', 1.8015895594373157e-05)
# (u'EMPLOYER_NAME_KAPRIS, INC', 1.7947702950841497e-05)
# (u'EMPLOYER_NAME_ROSEWICH ENGINEERING LLC', 1.7897986322168818e-05)
# (u'EMPLOYER_NAME_WEIL, GOTSHAL & MANGES LLP', 1.7897986322168818e-05)
# (u'EMPLOYER_NAME_LIGHTWAVES 2020, INC.', 1.7897986322168818e-05)
# (u'EMPLOYER_NAME_HERBALIFE INTERNATIONAL OF AMERICA, INC.', 1.7876685412821104e-05)
# (u'EMPLOYER_NAME_40 HRS., INC', 1.787450902529558e-05)
# (u'EMPLOYER_NAME_STERN PROJECTS, LLC', 1.7827243293227386e-05)
# (u'EMPLOYER_NAME_REGDESK INC.', 1.7820056047906796e-05)
# (u"EMPLOYER_NAME_ST. MARK'S WORLD, INC.", 1.7818713744954657e-05)
# (u'EMPLOYER_NAME_SHUTTERFLY, INC.', 1.780673298140558e-05)
# (u'EMPLOYER_NAME_FREMONT VETERINARY CLINIC', 1.7748836436150723e-05)
# (u'EMPLOYER_NAME_WALSINGHAM ACADEMY', 1.773829048461412e-05)
# (u'EMPLOYER_NAME_FEATHER TECHNOLOGIES, INC.', 1.7734408908242434e-05)
# (u'EMPLOYER_NAME_INVOCO ENTERPRISES', 1.7731202524175348e-05)
# (u'EMPLOYER_NAME_ANTHONY AURIEMMA USED AUTOMOTIVE CORES & METALS LLC.', 1.7708680697607544e-05)
# (u'EMPLOYER_NAME_CLARK CONSTRUCTION GROUP, LLC.', 1.764443151593801e-05)
# (u'EMPLOYER_NAME_FERRIER BRAND, LLC', 1.7592015486444975e-05)
# (u'EMPLOYER_NAME_COVENANT MEDICAL CENTER, INC.', 1.7542454617125746e-05)
# (u'EMPLOYER_NAME_COLUMBUS US INC.', 1.749005500998266e-05)
# (u'EMPLOYER_NAME_HUMMEL ARCHITECTS, PLLC.', 1.749005500998266e-05)
# (u'EMPLOYER_NAME_OPEL SYSTEMS, INC', 1.7480762573892628e-05)
# (u'EMPLOYER_NAME_DYS TECHNOLOGIES INC', 1.7439257003871334e-05)
# (u'EMPLOYER_NAME_BELLE FOUNTAIN REHABILITATION AND NURSING CENTER, INC.', 1.7411055811933525e-05)
# (u'EMPLOYER_NAME_MIC NETWORK, INC.', 1.7400820035441894e-05)
# (u'EMPLOYER_NAME_JLT RE (NORTH AMERICA) INC.', 1.7400820035441894e-05)
# (u'EMPLOYER_NAME_KCI TECHNOLOGIES, INC.', 1.7400820035441894e-05)
# (u'EMPLOYER_NAME_BROADCASTING YOUTH NETWORK INC', 1.738690732953131e-05)
# (u'EMPLOYER_NAME_AMERICAN TECH VISION SOLUTIONS LLC', 1.735668810916755e-05)
# (u'EMPLOYER_NAME_EOK TECHNOLOGIES, INC.', 1.7274704232384296e-05)
# (u'EMPLOYER_NAME_READING HOSPITAL', 1.7272570699939512e-05)
# (u'EMPLOYER_NAME_DECIPHER SOFTWARE SOLUTIONS', 1.719329985991491e-05)
# (u'EMPLOYER_NAME_IDEO LP', 1.712907697188933e-05)
# ('SOC_CODE_13-1022', 1.7123269765455124e-05)
# (u'EMPLOYER_NAME_LAS AMERICAS MULTIMEDIA GROUP, LLC', 1.7084441489342945e-05)
# (u'EMPLOYER_NAME_HOLSTON MEDICAL GROUP P C', 1.7084441489342945e-05)
# (u'EMPLOYER_NAME_YASHRAJ TECHNOLOGIES INC', 1.7072267970012335e-05)
# (u'EMPLOYER_NAME_EMD MILLIPORE CORPORATION', 1.7055728142301986e-05)
# (u'EMPLOYER_NAME_NATIONAL COUNCIL FOR BEHAVIORAL HEALTH', 1.7052543727040113e-05)
# (u'EMPLOYER_NAME_EALEARN INC', 1.7011188204324396e-05)
# (u'EMPLOYER_NAME_INNOVATIVE STAFFING SOLUTIONS', 1.70088673304741e-05)
# (u'EMPLOYER_NAME_STAR MANAGEMENT GROUP, LLC', 1.7005614970230237e-05)
# (u'EMPLOYER_NAME_GOKATECH INC', 1.6992288659305435e-05)
# (u'EMPLOYER_NAME_PEOPLE INFRA LLC', 1.69775568453907e-05)
# (u'EMPLOYER_NAME_VYZER SOLUTIONS INC', 1.6912870059644198e-05)
# (u'EMPLOYER_NAME_POINT EIGHT POWER, INC.', 1.6844842614797218e-05)
# (u'EMPLOYER_NAME_IDEA NUOVA INC', 1.684256042503776e-05)
# (u'EMPLOYER_NAME_CORE SOFTWARE TECHNOLOGIES INC', 1.6757166916654837e-05)
# (u'EMPLOYER_NAME_REHAB SPECIALISTS I, LLC', 1.675115721940662e-05)
# (u'EMPLOYER_NAME_LAUTERBACH, BORSCHOW & CO', 1.672773337033475e-05)
# (u'EMPLOYER_NAME_ZEN NETWORKS, LLC', 1.6704787234024223e-05)
# (u'EMPLOYER_NAME_NOBLESOFT SOLUTIONS, INC.', 1.6677926539363167e-05)
# (u'EMPLOYER_NAME_THE NIELSEN COMPANY (US), LLC', 1.667034437374772e-05)
# (u'EMPLOYER_NAME_RELIANCE INFORMATION TECHNOLOGY,INC', 1.6657149176702075e-05)
# (u'EMPLOYER_NAME_DATA CONCEPTS, LLC', 1.6639245611952913e-05)
# (u'EMPLOYER_NAME_STANDAV CORP.', 1.6600699097022616e-05)
# (u'EMPLOYER_NAME_MOBILECOMM PROFESSIONALS, INC.', 1.6581957916126984e-05)
# (u'EMPLOYER_NAME_TRADECO INFRASTRUCTURE, INC', 1.6581957916126984e-05)
# (u'EMPLOYER_NAME_RSG AERODESIGN, LLC', 1.6581957916126984e-05)
# (u'EMPLOYER_NAME_MERCURY SYSTEMS, INC.', 1.6558024228854064e-05)
# (u'EMPLOYER_NAME_DELTA GLOBAL SERVICES LLC', 1.6524006820061713e-05)
# (u'EMPLOYER_NAME_ANID INFOSOFT LLC', 1.6508793235116608e-05)
# (u'EMPLOYER_NAME_ARC THERAPY SERVICES, LLC', 1.6499260118362853e-05)
# (u'EMPLOYER_NAME_WINN-DIXIE STORES, INC.', 1.6485859824703162e-05)
# (u'EMPLOYER_NAME_10X GENOMICS, INC.', 1.6484987401997558e-05)
# (u'EMPLOYER_NAME_SEJALIT INC', 1.6484987401997558e-05)
# (u'EMPLOYER_NAME_BOSTON SYMPHONY ORCHESTRA', 1.6448053823665216e-05)
# (u'EMPLOYER_NAME_IBM INDIA PVT LTD', 1.6447844775150888e-05)
# (u'EMPLOYER_NAME_WESTERN DIGITAL TECHNOLOGIES, INC.', 1.63416396854585e-05)
# (u'EMPLOYER_NAME_GREATER BOSTON MANUFACTURING PARTNERSHIP INC', 1.6323138996272065e-05)
# (u'EMPLOYER_NAME_I2 INFOTECH, LLC', 1.617888476169399e-05)
# (u'EMPLOYER_NAME_RAMPS INTERNATIONAL, INC', 1.6037172509149078e-05)
# (u'EMPLOYER_NAME_SATYA MARG SOLUTIONS, INC', 1.5943729555542588e-05)
# (u'EMPLOYER_NAME_CREDENT TECHNOLOGIES LLC', 1.5851100917887854e-05)
# (u'EMPLOYER_NAME_ATOMIK IT, INC.', 1.5759277161703066e-05)
# (u'EMPLOYER_NAME_SSB SYSTEMS INC', 1.5668248988741446e-05)
# (u'EMPLOYER_NAME_NEW YORK UNIVERSITY HOSPITALS CENTER', 1.566073803189771e-05)
# (u'EMPLOYER_NAME_P&S CONSTRUCTION INC.', 1.566073803189771e-05)
# (u'EMPLOYER_NAME_CORPTEQ SOLUTIONS INC.', 1.5578007234649134e-05)
# (u'EMPLOYER_NAME_PRECISION X-RAY, INC.', 1.550254875884825e-05)
# (u'EMPLOYER_NAME_INTEGRETAS, INC', 1.5488542866626606e-05)
# (u'EMPLOYER_NAME_TERADYNE INFOTECH', 1.5444099415068446e-05)
# (u'EMPLOYER_NAME_GENOME INTERNATIONAL CORPORATION', 1.5399846981218257e-05)
# (u'EMPLOYER_NAME_ECONTENTI INC.', 1.531191080205219e-05)
# (u'EMPLOYER_NAME_ZYLOG SYSTEMS LIMITED', 1.5268224893914404e-05)
# (u'EMPLOYER_NAME_NEMO IT SOLUTIONS, INC', 1.5224725677692113e-05)
# (u"EMPLOYER_NAME_INTEL AMERICA'S", 1.5186170212749303e-05)
# (u'EMPLOYER_NAME_WIPRO LLC', 1.5091256648919803e-05)
# (u'EMPLOYER_NAME_SAPVIX INC', 1.4808364667539253e-05)
# (u'EMPLOYER_NAME_VALUELABS, INC', 1.42855395388888e-05)
# (u'EMPLOYER_NAME_CONCORD HOSPITAL', 1.3982801814194363e-05)
# (u'EMPLOYER_NAME_RAINTREE HEALTHCARE STAFFING, INC', 1.3882412467836148e-05)
# (u'EMPLOYER_NAME_OPENBOX SOLUTIONS, INC.', 1.3282132610122848e-05)
# (u'EMPLOYER_NAME_BHRIGUS, INC.', 1.3238024241133343e-05)
# (u'EMPLOYER_NAME_DW MATRIX INC', 1.3150464112134013e-05)
# (u'EMPLOYER_NAME_VIRGO INC', 1.3107009459964001e-05)
# (u'EMPLOYER_NAME_EDGEIT CORP', 1.3063769841127295e-05)
# (u'EMPLOYER_NAME_SOFTLABZ CORPORATION', 1.302074383918378e-05)
# (u'EMPLOYER_NAME_COGENT INTEGRATED BUSINESS SOLUTIONS INC', 1.2977930049330176e-05)
# (u'EMPLOYER_NAME_NUVIEW TECHNOLOGIES, INC.', 1.293532707830521e-05)
# (u'EMPLOYER_NAME_AMERICAN TECHNOLOGY LABS INC', 1.289460144930593e-05)
# (u'EMPLOYER_NAME_SOFTPATH TECHNOLOGIES, LLC', 1.289293354424274e-05)
# (u'EMPLOYER_NAME_HORIZON ADVANCED SYSTEMS INC', 1.2808769316061956e-05)
# (u'EMPLOYER_NAME_DILIGENT GROUP LLC', 1.2699974834424588e-05)
# (u'EMPLOYER_NAME_ROBERT A.M. STERN ARCHITECTS', 1.267774031153626e-05)
# (u'EMPLOYER_NAME_COGENT INFOTECH CORPORATION', 1.2594252183793415e-05)
# (u'EMPLOYER_NAME_INPHI CORPORATION', 1.2528590425518167e-05)
# (u'EMPLOYER_NAME_CYPROTEX US, LLC', 1.2528590425518167e-05)
# (u'EMPLOYER_NAME_SRIVEN TECHNOLOGIES, LLC', 1.2489844213295804e-05)
# (u'EMPLOYER_NAME_AMERICAN BUSINESS SOLUTIONS, INC.', 1.2471519363976432e-05)
# (u'EMPLOYER_NAME_PREMIER IT SOLUTIONS, INC', 1.2438126431865025e-05)
# (u'EMPLOYER_NAME_QUICKBASE, INC.', 1.2429157168172763e-05)
# (u'EMPLOYER_NAME_BARNEY A CAGLE', 1.2360030782426806e-05)
# (u'EMPLOYER_NAME_EPEOPLE TECHNOLOGIES INC', 1.2335649919480754e-05)
# (u'EMPLOYER_NAME_AGILITY TECHNOLOGIES, LLC', 1.228488592803621e-05)
# (u'EMPLOYER_NAME_KPIT INFOSYSTEMS, INC.', 1.2194686624384605e-05)
# (u'EMPLOYER_NAME_PRECISION TECHNOLOGIES CORP.', 1.2184293525505004e-05)
# (u'EMPLOYER_NAME_CEREBRA CONSULTING, INC.', 1.2134460014158843e-05)
# (u'EMPLOYER_NAME_I28 TECHNOLOGIES CORPORATION', 1.2084931605933259e-05)
# (u'EMPLOYER_NAME_TRUSTEK INC.', 1.1992835955733469e-05)
# (u'EMPLOYER_NAME_INFOGAIN CORPORATION', 1.1441533290183153e-05)
# (u'EMPLOYER_NAME_RELIABLE SOFTWARE RESOURCES, INC.', 1.1177954334481323e-05)
# (u'EMPLOYER_NAME_SUN SOFT TECHNOLOGIES, INC', 1.0735892902920084e-05)
# (u'EMPLOYER_NAME_SAIPSIT, INC.', 1.0553273990322459e-05)
# (u'EMPLOYER_NAME_UNIVERSAL SOFTWARE CORPORATION', 1.0505842429439502e-05)
# (u'EMPLOYER_NAME_VISUAL BI SOLUTIONS, INC.', 1.0463706935744122e-05)
# (u'EMPLOYER_NAME_AMZUR TECHNOLOGIES, INC', 1.0448022713265488e-05)
# (u'EMPLOYER_NAME_THE CHRIST HOSPITAL', 1.0440492021265146e-05)
# (u'EMPLOYER_NAME_QORVO US, INC.', 1.0440492021265137e-05)
# (u'EMPLOYER_NAME_LA VENTANA DE LOS CIELOS INC.', 1.0440492021265137e-05)
# (u'EMPLOYER_NAME_STE 212 INC', 1.0440492021265137e-05)
# ('SOC_CODE_45-2091', 1.0440492021265137e-05)
# (u'EMPLOYER_NAME_BITWISE INC.', 1.0390679010110476e-05)
# (u'EMPLOYER_NAME_ASPIRE SYSTEMS, INC.', 1.0375275313061247e-05)
# (u'EMPLOYER_NAME_N15 ARCHITECTURE COMPANY, INC.', 1.0367820557611604e-05)
# (u'EMPLOYER_NAME_EMERALD FIRE LLC', 1.0319784323370298e-05)
# (u'EMPLOYER_NAME_ERP ANALYSTS, INC.', 1.0238638799240607e-05)
# (u'EMPLOYER_NAME_NISUM TECHNOLOGIES INC.', 1.0145018272305064e-05)
# (u'EMPLOYER_NAME_ZYLOG SYSTEMS LTD.', 1.0110920773957937e-05)
# (u'EMPLOYER_NAME_INTERNATIONAL TECHNOLOGY SOLUTIONS, INC', 1.0002172555085607e-05)
# (u'EMPLOYER_NAME_SPLENDTEK INC', 9.948455194420785e-06)
# (u'EMPLOYER_NAME_AMERICAN EXPRESS TRAVEL RELATED SERVICES COMPANY, INC.', 9.607349778663398e-06)
# (u'EMPLOYER_NAME_WORLDSCAPE, INC.', 9.3370240237189e-06)
# (u'EMPLOYER_NAME_AMERICAN INFORMATION TECHNOLOGY CORPORATION', 9.207494231297172e-06)
# (u'EMPLOYER_NAME_LUCID TECHNOLOGIES,LLC', 9.018195586155443e-06)
# (u'EMPLOYER_NAME_AQUA INFORMATION SYSTEMS, INC.', 8.938227169253664e-06)
# (u'EMPLOYER_NAME_MILLENNIUM INFO TECH, INC.', 8.89522127105767e-06)
# (u'EMPLOYER_NAME_MSRCOSMOS, LLC', 8.89153203385347e-06)
# (u'EMPLOYER_NAME_NITEOSOFT INC', 8.79923286200967e-06)
# (u'EMPLOYER_NAME_AIRYSOFT, INC', 8.656700384168654e-06)
# (u'EMPLOYER_NAME_POLAR IT SERVICES INC', 8.598569212023142e-06)
# (u'EMPLOYER_NAME_XENOBIOTIC LABORATORIES INC A DIV OF WUXI', 8.352393617012112e-06)
# (u'EMPLOYER_NAME_THE PENNSYLVANIA HOSPITAL OF THE UNIVERSITY OF PENNSYLVANIA HEALTH SYS', 8.352393617012112e-06)
# (u'EMPLOYER_NAME_ISPRINT TECHNOLOGIES LLC', 8.04712521800083e-06)
# (u'EMPLOYER_NAME_ETOUCH SYSTEMS CORPORATION', 7.915553446134199e-06)
# (u'EMPLOYER_NAME_YASME SOFT, INC.', 7.782111703099776e-06)
# (u'EMPLOYER_NAME_MARLABS, INC', 7.2719488626382234e-06)
# (u'EMPLOYER_NAME_SQA CONCEPTS INC', 7.202026277419983e-06)
# (u'EMPLOYER_NAME_CAMELOT INTEGRATED SOLUTIONS INC', 7.171299557940653e-06)
# (u'EMPLOYER_NAME_CONNVERTEX TECHNOLOGIES INC.', 7.1331073656712676e-06)
# (u'EMPLOYER_NAME_INDUS VALLEY CONSULTANTS, INC.', 7.117956557974864e-06)
# (u'EMPLOYER_NAME_ALLIED INFORMATICS, INC', 6.998204545259299e-06)
# (u'EMPLOYER_NAME_BAIN & COMPANY, INC.', 6.869660696545425e-06)
# (u'EMPLOYER_NAME_SOFTPATH SYSTEM LLC', 6.618068558221217e-06)
# (u'EMPLOYER_NAME_GOMIAPP LLC', 6.545431220393655e-06)
# (u'EMPLOYER_NAME_ADAEQUARE INC', 5.993636975952569e-06)
# (u'EMPLOYER_NAME_LORSHI SYSTEMS, LLC', 5.602587557771738e-06)
# (u'EMPLOYER_NAME_STATE UNIVERSITY OF NEW YORK AT BINGHAMTON', 5.220246010632573e-06)
# (u'EMPLOYER_NAME_ONWARD INTERNATIONAL INC', 5.220246010632573e-06)
# (u'EMPLOYER_NAME_BAYOU LA BATRE AREA HEALTH DEVELOPMENT BOARD', 5.220246010632573e-06)
# (u'EMPLOYER_NAME_3I INFOTECH, INC.', 5.103086333162367e-06)
# (u'EMPLOYER_NAME_DELSUR TRADING LLC', 3.132147606379531e-06)
# (u'EMPLOYER_NAME_THE BOSTON CONSULTING GROUP, INC.', 2.798940414211277e-06)
# (u'EMPLOYER_NAME_THE BOSTON EDUCATION DEVELOPMENT FOUNDATION, INC.', 2.0880984042530415e-06)
# (u"EMPLOYER_NAME_CINCINNATI CHILDREN'S HOSPITAL MEDICAL CENTER", 2.088098404253028e-06)
# (u'EMPLOYER_NAME_GOLDEN BRIDGE HOLIDAY, INC.', 1.1186241451355399e-06)
# (u'EMPLOYER_NAME_BKD INCORPORATE', 8.70041001772092e-07)
# (u'EMPLOYER_NAME_OJALA LTD DBA NAVIA', 6.960328014176945e-07)
# (u'EMPLOYER_NAME_THE HOSPITALITY SWEET, LLC', 5.694813829780883e-07)
# (u'EMPLOYER_NAME_RESPONDENT INC', 4.7456781914841507e-07)
# (u'EMPLOYER_NAME_FREMONT CABINET IMPORTS, INC', 4.015573854332454e-07)
# (u'EMPLOYER_NAME_STW ENTERPRISE, INC.', 3.4419204465713305e-07)
# (u'EMPLOYER_NAME_SASHA ESPOSITO SAN ROMAN, MARRIAGE AND FAMILY THERAPIST, MA, MFT, INC', 2.9829977203614585e-07)
# (u'EMPLOYER_NAME_DYNAMICS EXECUTIVE SEARCH', 2.6101230053161366e-07)
# (u'EMPLOYER_NAME_EMANDI LAW FIRM PC', 2.3030497105733235e-07)
# (u'EMPLOYER_NAME_DELSAV, INC', 2.047155298287275e-07)
# (u'EMPLOYER_NAME_COT INC', 1.8316652668888122e-07)
# (u'EMPLOYER_NAME_GALEN TECHNOLOGY SOLUTIONS, INC.', 1.6484987401992774e-07)
# (u"EMPLOYER_NAME_VICKI'S FRESH FOOD MOVEMENT, LTD.", 1.4914988601810768e-07)
# (u'EMPLOYER_NAME_SKYWALKER COMMUNICATIONS GROUP, LLC.', 1.3559080547098864e-07)
# (u'EMPLOYER_NAME_TURKON AMERICA INC', 1.2380030064739812e-07)
# (u'EMPLOYER_NAME_DAHO USA LLC', 1.1348360892681638e-07)
# (u'EMPLOYER_NAME_BOSTON INNOVATION GATEWAY LLC', 9.674587201178293e-08)
# (u'EMPLOYER_NAME_TONY WONG & ASSOCIATES, LAWYERS, INC.', 9.637377250403844e-08)
# (u'EMPLOYER_NAME_ANTI-AGING CLINIC LLC', 8.923497454066712e-08)
# (u'EMPLOYER_NAME_MANDARIN GARDEN WENG LLC', 8.682321847195043e-08)
# (u'EMPLOYER_NAME_THE BOSTON EDUCATION DEVELOPMENT FOUNDATION', 8.286104778783683e-08)
# (u'EMPLOYER_NAME_GENERAL INTERNATIONAL FREIGHT FORWARDERS, INC.', 7.835266057242265e-08)
# (u'EMPLOYER_NAME_LAKE ALPINE RESORT INC', 7.714649276792893e-08)
# (u'EMPLOYER_NAME_CITY OCEAN INTERNATIONAL, INC.', 7.200339325012311e-08)
# (u'EMPLOYER_NAME_DOLLS KILL INC.', 7.106404098424763e-08)
# (u'EMPLOYER_NAME_ECODISTRICTS', 6.735801304040767e-08)
# (u'EMPLOYER_NAME_THE IWAY GROUP, INC.', 6.474723734117279e-08)
# (u'EMPLOYER_NAME_SPLIT SECOND SOUND', 6.314813722543393e-08)
# (u'EMPLOYER_NAME_KREMENCHUKER LAW FIRM', 5.9320977393511895e-08)
# (u'EMPLOYER_NAME_AUDITRAX, LLC', 5.923683416321351e-08)
# (u'EMPLOYER_NAME_THE DEPARTMENT OF SALES INC.', 5.583150813513343e-08)
# (u'EMPLOYER_NAME_CHICAGO TEMPERED GLASS INC.', 5.440117423148883e-08)
# (u'EMPLOYER_NAME_THE ASIA GROUP, LLC', 5.26411362416867e-08)
# (u'EMPLOYER_NAME_CITY OF BLUEFIELD', 5.013441546830749e-08)

# %% [markdown]
# Evaluate a naive classifier which predicts a case is always denied if wage is lower than PW. It is always certified otherwise.

# %%
status_stats = df.groupby('CASE_STATUS').size().to_frame()
status_stats['percentage'] = status_stats[0] / status_stats[0].sum()
print(status_stats)
# Out:
#                   0  percentage
# CASE_STATUS
# CERTIFIED    270302    0.795825
# DENIED        69348    0.204175

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, fbeta_score, accuracy_score, confusion_matrix


naive_prediction = X_test['WAGE_LOWER_THAN_PW']
print("** Naive Classifier Scores (Overall)")
print("Precision: %s"% precision_score(y_test, naive_prediction))
print("Recall: %s"% recall_score(y_test, naive_prediction))
print("Accuracy score: %s"% accuracy_score(y_test, naive_prediction))
print("F-1 score: %s"% f1_score(y_test, naive_prediction))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_test, naive_prediction, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_test, naive_prediction, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_test, naive_prediction))
# Out:
# ** Naive Classifier Scores (Overall)
# Precision: 0.99568345323741
# Recall: 0.18500200507953482
# Accuracy score: 0.6443887658781028
# F-1 score: 0.3120279562619772
# F-beta score with beta=0.5: 0.5306341538225596
# F-beta score with beta=0.2: 0.8520754895692736
# Confusion Matrix:
# [[9675    6]
#  [6097 1384]]
