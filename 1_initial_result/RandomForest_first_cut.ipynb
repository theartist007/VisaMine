# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Load cleaned up version of dataset from 2015 to 2018.  Drop geographic information about employer and worksite to reduce dimensionality

# %%
df = pd.read_pickle('/Users/ml/Desktop/Udacity_ML_Capstone/data/H1B_15-18_FINAL.pickle')
df.drop(columns=['EMPLOYER_CITY','EMPLOYER_STATE','WORKSITE_STATE'], inplace=True)

# %% [markdown]
# Show first 5 lines of the dataset

# %%
df.head()
# Out:
#    CASE_STATUS FULL_TIME_POSITION H1B_DEPENDENT NAICS_CODE  PREVAILING_WAGE  \
# 3    CERTIFIED                  Y             N     335314     70413.266200
# 4    CERTIFIED                  Y             N     522294    103390.078300
# 7    CERTIFIED                  Y             N     522294     68372.286500
# 9       DENIED                  N             N     424460        23.962574
# 11      DENIED                  Y             N     541330    368080.500000
#
#    PW_SOURCE SOC_CODE VISA_CLASS WAGE_UNIT_OF_PAY WILLFUL_VIOLATOR  \
# 3        OES  17-2072       H-1B             Year                N
# 4        OES  15-1131       H-1B             Year                N
# 7        OES  15-2031       H-1B             Year                N
# 9      Other  13-2011       H-1B             Hour                N
# 11       DBA  13-2011       H-1B             Year                N
#
#     WAGE_LOWER_THAN_PW
# 3                False
# 4                False
# 7                False
# 9                False
# 11                True

# %% [markdown]
# We will use column 'CASE_STATUS' as our label.  DENIED will be 1 and CERTIFIED will be 0 after it gets incoded by label_encoder.
#
# Normalize PREVAILING_WAGE using minmax scaler since it varies quite a bit.

# %%
scaler = MinMaxScaler()
X = df.drop(columns='CASE_STATUS')

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['CASE_STATUS'])

X[['PREVAILING_WAGE']] = scaler.fit_transform(X[['PREVAILING_WAGE']])
X = pd.get_dummies(X)

# %%
ones_index
# Out:
# (array([     9,     20,     39, ..., 305219, 305246, 305279]),)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# %% [markdown]
# Check value counts to verify stratify split

# %%
X_train.head()
# Out:
#         PREVAILING_WAGE  WAGE_LOWER_THAN_PW  FULL_TIME_POSITION_N  \
# 248404         0.000108               False                     0
# 256348         0.000065               False                     0
# 542928         0.000087               False                     0
# 401956         0.000049               False                     0
# 133647         0.000084               False                     0
#
#         FULL_TIME_POSITION_Y  H1B_DEPENDENT_N  H1B_DEPENDENT_Y  \
# 248404                     1                0                1
# 256348                     1                1                0
# 542928                     1                0                1
# 401956                     1                1                0
# 133647                     1                1                0
#
#         NAICS_CODE_106888  NAICS_CODE_11 MM ACRES ENERGY, LLC  \
# 248404                  0                                   0
# 256348                  0                                   0
# 542928                  0                                   0
# 401956                  0                                   0
# 133647                  0                                   0
#
#         NAICS_CODE_111100  NAICS_CODE_11111         ...          \
# 248404                  0                 0         ...
# 256348                  0                 0         ...
# 542928                  0                 0         ...
# 401956                  0                 0         ...
# 133647                  0                 0         ...
#
#         VISA_CLASS_H-1B  VISA_CLASS_H-1B1 Chile  VISA_CLASS_H-1B1 Singapore  \
# 248404                1                       0                           0
# 256348                1                       0                           0
# 542928                1                       0                           0
# 401956                1                       0                           0
# 133647                1                       0                           0
#
#         WAGE_UNIT_OF_PAY_Bi-Weekly  WAGE_UNIT_OF_PAY_Hour  \
# 248404                           0                      0
# 256348                           0                      0
# 542928                           0                      0
# 401956                           0                      0
# 133647                           0                      0
#
#         WAGE_UNIT_OF_PAY_Month  WAGE_UNIT_OF_PAY_Week  WAGE_UNIT_OF_PAY_Year  \
# 248404                       0                      0                      1
# 256348                       0                      0                      1
# 542928                       0                      0                      1
# 401956                       0                      0                      1
# 133647                       0                      0                      1
#
#         WILLFUL_VIOLATOR_N  WILLFUL_VIOLATOR_Y
# 248404                   1                   0
# 256348                   1                   0
# 542928                   1                   0
# 401956                   1                   0
# 133647                   1                   0
#
# [5 rows x 5370 columns]

# %% [markdown]
# Train DecisionTreeClassifier and predict using X_test

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# print(clf.feature_importances_)
print(clf.score(X_test, y_test))
tree_pred = clf.predict(X_test)
print(tree_pred)
# for i in range(len(y_hat)):
#     if y_test[i]==1:
#         print("{}:: {}".format(y_test[i],y_hat[i]))
# Out:
# 0.9785590053160304
# [0 0 0 ... 0 0 0]

# %% [markdown]
# Train RandomForestClassifier and predict using X_test

# %%
from sklearn.ensemble import RandomForestClassifier


# from sklearn.feature_extraction.text import CountVectorizer

rfc = RandomForestClassifier()
# vec = CountVectorizer()
# X_train_t = vec.fit_transform(X_train)

rfc.fit(X_train, y_train)

rfc_pred = rfc.predict(X_test)
# Out:
# /Users/ml/ml_env/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from sklearn.metrics import classification_report, confusion_matrix
print("** Decision tree Classifier Stats (OVERALL testset)")
print(classification_report(y_test, tree_pred))

print("** Random Forest Classifier Stats (OVERALL testset)")
print(classification_report(y_test, rfc_pred))
# Out:
# ** Decision tree Classifier Stats (OVERALL testset)
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99    297848
#           1       0.61      0.35      0.44      7455
#
# avg / total       0.97      0.98      0.98    305303
#
# ** Random Forest Classifier Stats (OVERALL testset)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99    297848
#           1       0.64      0.34      0.44      7455
#
# avg / total       0.98      0.98      0.98    305303

# %% [markdown]
# Output the feature importance vector and sort by importance

# %%
import operator
# print(len(rfc.feature_importances_))
# print(len(X_train.columns))

nonzero_features = {}
for i in range(len(rfc.feature_importances_)):
    if rfc.feature_importances_[i] > 0.0:
        nonzero_features[list(X_train.columns)[i]] = rfc.feature_importances_[i]
sorted_result = sorted(nonzero_features.items(), key=operator.itemgetter(1)) 
for i in range(len(sorted_result)):
    print(sorted_result[-(i+1)])
# Out:
# (u'PREVAILING_WAGE', 0.30899545494138314)
# ('WAGE_LOWER_THAN_PW', 0.20799220356298184)
# (u'VISA_CLASS_H-1B', 0.07309553354675245)
# (u'VISA_CLASS_E-3 Australian', 0.03703164660393674)
# (u'WAGE_UNIT_OF_PAY_Year', 0.00723855015847052)
# (u'WAGE_UNIT_OF_PAY_Hour', 0.005921642991539291)
# (u'PW_SOURCE_OES', 0.004133008749398209)
# ('NAICS_CODE_541511', 0.00412464229878589)
# (u'NAICS_CODE_CAPGEMINI AMERICA INC', 0.003896443595411902)
# (u'H1B_DEPENDENT_N', 0.003580174662405468)
# (u'PW_SOURCE_Other', 0.003464124034837413)
# (u'H1B_DEPENDENT_Y', 0.003291746312051908)
# (u'WAGE_UNIT_OF_PAY_Month', 0.0031273966585035617)
# ('SOC_CODE_13-2011', 0.002850158925323578)
# ('SOC_CODE_13-1161', 0.0023485437600034914)
# ('SOC_CODE_15-1132', 0.0021930398079176606)
# (u'FULL_TIME_POSITION_Y', 0.00198517436002186)
# (u'VISA_CLASS_H-1B1 Chile', 0.0017893808141050162)
# (u'WAGE_UNIT_OF_PAY_Week', 0.0017785117487997455)
# ('NAICS_CODE_611310', 0.0017709225062104022)
# (u'FULL_TIME_POSITION_N', 0.0016646008900755502)
# ('SOC_CODE_15-1121', 0.0016275428229251508)
# ('SOC_CODE_13-1111', 0.0015943227296527217)
# (u'VISA_CLASS_H-1B1 Singapore', 0.0015767085777642787)
# (u'NAICS_CODE_ACCENTURE LLP', 0.0015493689287434873)
# ('SOC_CODE_15-1199', 0.001474217879660227)
# ('SOC_CODE_13-2051', 0.001425953458448837)
# ('SOC_CODE_17-2112', 0.0013929240623075801)
# ('SOC_CODE_11-2021', 0.0013647529823705897)
# ('NAICS_CODE_541330', 0.0013593602338438434)
# (u'NAICS_CODE_NCS PEARSON, INC.', 0.0013016702027241857)
# ('SOC_CODE_17-2071', 0.0012529810912248356)
# ('SOC_CODE_15-1142', 0.001219349852495564)
# ('SOC_CODE_11-1021', 0.0012186786175096063)
# ('NAICS_CODE_541512', 0.0012096884323540649)
# ('NAICS_CODE_622110', 0.001209237711975858)
# (u'WAGE_UNIT_OF_PAY_Bi-Weekly', 0.0011870843254774357)
# ('SOC_CODE_17-2141', 0.00117867032525287)
# ('NAICS_CODE_541519', 0.0011618632938092247)
# ('SOC_CODE_11-3021', 0.0011352688872403433)
# (u'NAICS_CODE_CUMMINS INC.', 0.001115175411245178)
# (u'PW_SOURCE_CBA', 0.0011110799701112297)
# ('SOC_CODE_15-2031', 0.001056501216555973)
# (u'PW_SOURCE_SCA', 0.0010384342885748706)
# ('NAICS_CODE_541990', 0.0010384089785008654)
# ('NAICS_CODE_54161', 0.0010368919265059274)
# ('SOC_CODE_15-1131', 0.001029191017649412)
# ('SOC_CODE_17-2199', 0.001000942055710107)
# ('SOC_CODE_17-2051', 0.0009977291480798428)
# ('SOC_CODE_15-1141', 0.0009896132797168028)
# ('NAICS_CODE_541611', 0.0009344924361125932)
# ('SOC_CODE_27-3031', 0.0009168341697152783)
# ('NAICS_CODE_541710', 0.000913874758977283)
# (u'PW_SOURCE_DBA', 0.0008970937318155076)
# ('SOC_CODE_29-1123', 0.0008802542306181937)
# ('NAICS_CODE_511210', 0.0008671252171378252)
# ('SOC_CODE_15-1133', 0.0008589677525858454)
# ('SOC_CODE_11-3031', 0.0008412248799249435)
# ('NAICS_CODE_541690', 0.0008314739479317686)
# ('SOC_CODE_27-1024', 0.0008291830668421653)
# ('NAICS_CODE_621111', 0.0008268591202427953)
# ('SOC_CODE_11-1011', 0.0008139836352370923)
# ('NAICS_CODE_541613', 0.0007950895953593766)
# ('SOC_CODE_13-1081', 0.0007892602932927774)
# (u'NAICS_CODE_EXPEDIA, INC.', 0.0007787706591655167)
# ('NAICS_CODE_611110', 0.0007552084110152666)
# ('SOC_CODE_11-9041', 0.0007454095035216619)
# ('SOC_CODE_23-2011', 0.0007313263036200775)
# ('NAICS_CODE_532111', 0.00013543039274229094)
# ('NAICS_CODE_611630', 0.0001353587793641656)
# ('NAICS_CODE_61163', 0.0001352705137806716)
# ('SOC_CODE_15-1052', 0.00013508589487336056)
# (u'NAICS_CODE_KODER, INC.', 0.0001345435765283834)
# ('NAICS_CODE_531311', 0.00013423287039069227)
# (u'NAICS_CODE_G-TECH PROFESSIONAL STAFFING, INC.', 0.0001342126557746653)
# (u'NAICS_CODE_CLOUD COUNTY COMMUNITY COLLEGE', 0.0001341206967975349)
# (u'NAICS_CODE_NOBLE HOUSE HOME FURNISHINGS, LLC', 0.0001339922299012178)
# ('NAICS_CODE_332611', 0.0001339824800734713)
# ('NAICS_CODE_54162', 0.00013390838032992773)
# (u'NAICS_CODE_CHADSEL, LLC', 0.00013378310432341544)
# (u'NAICS_CODE_PHDATA, INC.', 0.000133730018302769)
# ('SOC_CODE_17-2144', 0.00013349894053529156)
# ('SOC_CODE_45-2011', 0.00013313644819248948)
# ('SOC_CODE_29-1129', 0.00013271757409370728)
# ('SOC_CODE_31-9091', 0.00013265821864931617)
# ('SOC_CODE_25-1194', 0.0001325970888165564)
# (u'NAICS_CODE_GUYMON PUBLIC SCHOOL', 0.00013212633858503397)
# ('NAICS_CODE_813212', 0.0001320444477241844)
# ('SOC_CODE_19-1013', 0.00013192349485434808)
# ('NAICS_CODE_334513', 0.00013160555769427674)
# ('SOC_CODE_35-3031', 0.00013158170641719668)
# (u'NAICS_CODE_ARICENT TECHNOLOGIES (HOLDINGS) LTD.', 0.00013112054749893207)
# ('NAICS_CODE_424480', 0.0001309915345031731)
# ('NAICS_CODE_541199', 0.0001307814271518174)
# (u'NAICS_CODE_USA WASTE-MANAGEMENT RESOURCES, L.L.C.', 0.00013055786578890466)
# ('NAICS_CODE_423490', 0.00013054338376428974)
# ('SOC_CODE_15-1021', 0.00013023081362829338)
# ('NAICS_CODE_492210', 0.00013021748783567552)
# (u'NAICS_CODE_HAMPTON ROADS MONTESSORI SCHOOL', 0.00012944185223648824)
# ('NAICS_CODE_56149', 0.00012932756336574863)
# ('SOC_CODE_13-2041', 0.0001289243411807724)
# ('SOC_CODE_29-9099', 0.00012862593277812568)
# ('NAICS_CODE_811213', 0.00012840405561694777)
# (u'NAICS_CODE_LINKEDROAD INC', 0.00012703806349548022)
# (u'NAICS_CODE_VICTORY SYSTEMS, INC.', 0.00012696706534211214)
# ('NAICS_CODE_624110', 0.00012681289930397373)
# ('NAICS_CODE_488190', 0.00012652233641021585)
# ('NAICS_CODE_331511', 0.00012618526526417275)
# ('NAICS_CODE_238340', 0.0001260583971232999)
# ('NAICS_CODE_42339', 0.00012602675098642786)
# ('NAICS_CODE_335999', 0.00012546069645369857)
# ('NAICS_CODE_312140', 0.00012521281442473808)
# ('NAICS_CODE_448190', 0.00012515480800291234)
# (u'NAICS_CODE_WOODLAND EQUITY, LLC', 0.00012502755613488873)
# ('NAICS_CODE_321911', 0.00012496675570349366)
# ('NAICS_CODE_23821', 0.00012431491774605178)
# ('NAICS_CODE_712110', 0.00012418510353826327)
# ('NAICS_CODE_62134', 0.00011531538914928603)
# ('NAICS_CODE_512131', 0.00011516150372467889)
# ('SOC_CODE_51-1011', 0.0001151499260582171)
# (u'NAICS_CODE_ROTECH SOLUTIONS LLC', 0.00011487762178656385)
# ('NAICS_CODE_42343', 0.00011447979513019849)
# ('NAICS_CODE_33411', 0.00011432734434761062)
# (u'NAICS_CODE_GRACE WILLIAMS CPA PC', 0.00011419670272386352)
# (u'NAICS_CODE_CANCER RESEARCH INSTITUTE INC', 0.00011409128349875697)
# (u'NAICS_CODE_KERN PSYCHIATRIC HEALTH AND WELLNESS CENTER INC', 0.00011356404317367796)
# ('NAICS_CODE_481111', 0.00011349055851422193)
# ('NAICS_CODE_312112', 0.00011336148017685962)
# (u'NAICS_CODE_AMERICAN CORPORATE SERVICES, INC.', 0.00011318779100609458)
# ('NAICS_CODE_339900', 0.0001131458501030102)
# (u'NAICS_CODE_MARYLAND HEALTHCARE PC', 0.00011283230144291659)
# (u'NAICS_CODE_EVEREST GLOBAL SOLUTIONS INC', 0.00011262511265655219)
# (u'NAICS_CODE_SILVERROCK LLC', 0.00011221655809400723)
# ('NAICS_CODE_42311', 0.00011212708790440368)
# (u'NAICS_CODE_NATURE OF MARBLE , INC', 0.00011206502624233883)
# (u'NAICS_CODE_CITY OF HINESVILLE', 0.00011203906224485261)
# ('NAICS_CODE_813930', 0.00011187416045313012)
# ('NAICS_CODE_423510', 0.00011185125134372236)
# ('NAICS_CODE_332999', 0.00011167659537560523)
# ('NAICS_CODE_447110', 0.00011164522444838228)
# ('SOC_CODE_15-1036', 0.00011162528534899606)
# ('NAICS_CODE_326199', 0.00011145742737821542)
# ('NAICS_CODE_61151', 0.00011127406364171866)
# ('SOC_CODE_29-1029', 0.00011117686508344449)
# ('NAICS_CODE_42442', 0.00011104270889917048)
# ('NAICS_CODE_711219', 0.00011103424451361817)
# ('NAICS_CODE_621991', 0.00011091396860650041)
# ('NAICS_CODE_42345', 0.00011090078051682847)
# ('NAICS_CODE_611420', 0.00011037600476121879)
# (u'NAICS_CODE_TRIANGLE ACCOUNTING, INC.', 0.00011019019622699991)
# (u'NAICS_CODE_GOODWATER CAPITAL, LLC', 0.00011018430153060337)
# (u'NAICS_CODE_RAZZ INTERACTIVE, LLC', 0.0001097245179813392)
# ('NAICS_CODE_44131', 0.00010955762756265073)
# (u'NAICS_CODE_CUMMINS EMISSION SOLUTIONS INC.', 0.00010876046285942515)
# ('SOC_CODE_25-3021', 0.000108743389112508)
# (u'NAICS_CODE_FLORIDA BC HOLDINGS, LLC', 0.00010862129322449526)
# ('SOC_CODE_51-9199', 0.00010857025358931118)
# (u'NAICS_CODE_ATEKON INVESTMENT, LLC', 0.00010851107791968792)
# (u'NAICS_CODE_PALI MOUTAIN', 0.00010782782022648632)
# ('NAICS_CODE_713990', 0.0001077106721881505)
# ('NAICS_CODE_333132', 0.00010738655521836597)
# ('SOC_CODE_37-2012', 0.00010737179160796638)
# (u'NAICS_CODE_HITACHI SOLUTONS AMERICA, LTD.', 0.0001072967435187063)
# ('SOC_CODE_41-3031', 0.00010728942211730144)
# (u'NAICS_CODE_FAMILIA DENTAL RIVER GLEN LLC', 9.050877309576549e-05)
# ('NAICS_CODE_518111', 9.04761821143271e-05)
# ('SOC_CODE_45-2099', 9.043591357713726e-05)
# ('SOC_CODE_17-2111', 9.029359446323628e-05)
# ('NAICS_CODE_562991', 9.024363298437837e-05)
# ('NAICS_CODE_334290', 9.01160123967085e-05)
# ('SOC_CODE_19-1023', 8.987739363991752e-05)
# (u'NAICS_CODE_KTB FLORIDA SPORTS ARENA LLC', 8.986333562495726e-05)
# ('NAICS_CODE_332322', 8.983143392006371e-05)
# ('NAICS_CODE_323110', 8.971531970851924e-05)
# ('NAICS_CODE_561920', 8.966183273412067e-05)
# ('SOC_CODE_21-2011', 8.951401065192182e-05)
# (u'NAICS_CODE_GINA GROUP LLC', 8.949020328487493e-05)
# ('NAICS_CODE_541300', 8.945130640854293e-05)
# ('NAICS_CODE_333993', 8.925339512541101e-05)
# ('SOC_CODE_17-2121', 8.92370197837054e-05)
# (u'NAICS_CODE_ADIGE LLC', 8.914111960488775e-05)
# ('NAICS_CODE_237120', 8.891699253120905e-05)
# ('NAICS_CODE_325413', 8.889177740392139e-05)
# ('NAICS_CODE_44711', 8.888486284747715e-05)
# ('NAICS_CODE_926140', 8.888293484439252e-05)
# ('NAICS_CODE_339914', 8.877678194493834e-05)
# (u'NAICS_CODE_CURATA, INC.', 8.864044412350383e-05)
# ('NAICS_CODE_813312', 8.847495743897644e-05)
# (u'NAICS_CODE_AIG GLOBAL SERVICES, INC.', 8.845045642455586e-05)
# ('SOC_CODE_21-2021', 8.827132055851378e-05)
# ('NAICS_CODE_72231', 8.822592691383975e-05)
# (u'NAICS_CODE_GOOD SAMARITAN HOSPITAL MEDICAL CENTER', 8.793640173784482e-05)
# ('SOC_CODE_41-9022', 8.788425626933677e-05)
# ('SOC_CODE_27-4011', 8.78061533693044e-05)
# ('NAICS_CODE_51811', 8.775907398668424e-05)
# (u'NAICS_CODE_SARAS FAMILY RESTAURANT INC', 8.775450485461409e-05)
# (u'NAICS_CODE_WATERONE', 8.758988064315064e-05)
# ('SOC_CODE_41-9012', 8.728657371948697e-05)
# (u'NAICS_CODE_MOULDING SPECIALIST INC', 8.710939635963533e-05)
# (u'NAICS_CODE_STERLING SOFTWARE INC.', 8.70958335427446e-05)
# (u'NAICS_CODE_WELLBRAIN INC', 8.70740786593446e-05)
# ('NAICS_CODE_56172', 8.695262646486602e-05)
# ('NAICS_CODE_48531', 8.694110544938828e-05)
# ('NAICS_CODE_334416', 8.689650118460535e-05)
# ('NAICS_CODE_541500', 8.683276516126167e-05)
# (u'NAICS_CODE_CHI, INC.', 8.669872181907741e-05)
# ('SOC_CODE_25-1041', 8.664669851944122e-05)
# ('NAICS_CODE_424460', 8.655598518200042e-05)
# ('NAICS_CODE_62199', 8.646961686094319e-05)
# ('NAICS_CODE_551000', 8.637989930590197e-05)
# (u'NAICS_CODE_UDATA ANALYSTS INC', 8.632279764463316e-05)
# (u'NAICS_CODE_CEDENT CONSULTING INC', 8.630678237290605e-05)
# (u'NAICS_CODE_IIG WIRELESS, INC.', 8.62930913027531e-05)
# (u'NAICS_CODE_NORTHSIDE CHARTER HIGH SCHOOL', 8.626529852348141e-05)
# (u'NAICS_CODE_ITALENTA INC', 8.618728122083394e-05)
# (u'NAICS_CODE_PRADON TECHNOLOGIES LLC', 8.611984903128544e-05)
# (u'NAICS_CODE_BLACK DIAMOND INVESTMENT GROUP LLC', 8.606772438467448e-05)
# ('NAICS_CODE_332211', 8.59934514037732e-05)
# (u'NAICS_CODE_WESTERN WASHINGTON CORPORATION OF SEVENTH DAY ADVENTISTS', 8.598006463459141e-05)
# (u'NAICS_CODE_AXIOM LIFE SCIENCE, LLC', 8.595945927027698e-05)
# (u'NAICS_CODE_GWM GROUP INC', 8.592618189492592e-05)
# (u'NAICS_CODE_ISSAM TINA SOLUTIONS INC', 8.588352099359621e-05)
# (u'NAICS_CODE_MICROSEMI STORAGE SOLUTIONS (U.S.), INC.', 8.581802329488903e-05)
# ('NAICS_CODE_337000', 8.57190846504212e-05)
# (u'NAICS_CODE_MUNILLA CONSTRUCTION MANAGEMENT LLC', 8.55441902169712e-05)
# (u'NAICS_CODE_CAPITOL SYSTEM SOLUTIONS LLC', 8.541969672216935e-05)
# ('NAICS_CODE_484121', 8.531904193438319e-05)
# ('SOC_CODE_43-5071', 8.506873898611485e-05)
# ('NAICS_CODE_311920', 8.500418010746935e-05)
# (u'NAICS_CODE_HDNS GROUP', 8.496374207077753e-05)
# ('SOC_CODE_49-1011', 8.484577643604926e-05)
# (u'NAICS_CODE_THE COSTAS NETWORK LAW CENTER LLC', 8.47717470152878e-05)
# ('SOC_CODE_25-1021', 8.476356675848963e-05)
# ('NAICS_CODE_71392', 8.473403550636459e-05)
# (u'NAICS_CODE_NORTHWEST DIGITS LLC', 8.470838390848205e-05)
# (u'NAICS_CODE_AUDITRAX, LLC', 8.46388911549709e-05)
# ('NAICS_CODE_322230', 8.46078109741545e-05)
# (u'NAICS_CODE_LAKE OCONEE ACADEMY, INC.', 8.445546370599322e-05)
# ('SOC_CODE_35-2021', 8.40687220334631e-05)
# ('NAICS_CODE_337110', 8.391121868242318e-05)
# ('NAICS_CODE_311000', 8.389364853473055e-05)
# ('SOC_CODE_43-9061', 8.386367906542892e-05)
# ('NAICS_CODE_62149', 8.386358371379005e-05)
# ('SOC_CODE_29-2012', 8.378454694700793e-05)
# (u'NAICS_CODE_WILLIAM E. JOHNSON ASSOCIATES', 8.3662929364527e-05)
# ('NAICS_CODE_336612', 8.349935554980623e-05)
# ('SOC_CODE_25-1126', 8.338393809284564e-05)
# ('NAICS_CODE_611699', 8.338310009725176e-05)
# (u'NAICS_CODE_LOGIK SYSTEMS INC', 8.324774843424462e-05)
# (u'NAICS_CODE_WORKDAY, INC.', 8.311604312325517e-05)
# ('NAICS_CODE_221310', 8.296948412028208e-05)
# ('SOC_CODE_13-1131', 8.295097529094041e-05)
# (u'NAICS_CODE_KW FASHION CORP.', 8.294485276209363e-05)
# ('NAICS_CODE_922110', 8.274695628427587e-05)
# ('NAICS_CODE_42511', 8.27167016057847e-05)
# (u'NAICS_CODE_STRATEGIC STAFFING SOLUTIONS, L.C.', 8.265715988128127e-05)
# (u'NAICS_CODE_SYMPLAST, LLC', 8.2515770312376e-05)
# ('NAICS_CODE_924110', 8.247977694928907e-05)
# ('NAICS_CODE_327211', 8.24515429840215e-05)
# (u'NAICS_CODE_RITCO FOODS LLC', 8.243706553285315e-05)
# ('NAICS_CODE_112210', 8.236370380438894e-05)
# ('NAICS_CODE_517110', 8.23400248354067e-05)
# ('SOC_CODE_43-4199', 8.232836890468224e-05)
# ('NAICS_CODE_61171', 8.220438074603602e-05)
# (u'NAICS_CODE_DREAMERS TECHNOLOGY CORP', 8.218311106252525e-05)
# (u'NAICS_CODE_NATIONAL FINANCIAL LLC', 8.217673687834664e-05)
# (u'NAICS_CODE_GENERAL INFORMATION SERVICES, INC.', 8.215512615148619e-05)
# ('SOC_CODE_17-3021', 8.20971673395216e-05)
# ('SOC_CODE_49-3021', 8.209309404186444e-05)
# (u'NAICS_CODE_ROSWELL ISD', 8.20725599215657e-05)
# ('SOC_CODE_47-2051', 8.198736627093283e-05)
# ('SOC_CODE_41-1011', 8.197103590244775e-05)
# (u'NAICS_CODE_OMM INC.', 8.19519589574859e-05)
# (u'NAICS_CODE_OUTCLICK MEDIA', 8.19302467230497e-05)
# ('SOC_CODE_19-3022', 8.192807361240707e-05)
# ('NAICS_CODE_422990', 8.178675339995148e-05)
# (u'NAICS_CODE_SAFE AUTO INSURANCE COMPANY', 8.175633982278418e-05)
# ('NAICS_CODE_115112', 8.147515542399804e-05)
# (u'NAICS_CODE_DFOCUS AMERICA INC', 8.133563817870048e-05)
# (u'NAICS_CODE_CALIFORNIA PREPARATORY COLLEGE', 8.130730363630905e-05)
# ('NAICS_CODE_112512', 8.123070601889514e-05)
# (u'NAICS_CODE_CHOBANI GLOBAL HOLDINGS, INC.', 8.110653173534725e-05)
# (u'NAICS_CODE_CMG WORLDWIDE, INC.', 8.097401094401296e-05)
# ('SOC_CODE_21-1093', 8.089476625948734e-05)
# (u'NAICS_CODE_CENTRAL ALABAMA COMMUNITY COLLEGE', 8.086257414528862e-05)
# (u'NAICS_CODE_WONG MUI & CHIAO, LLP', 8.08306568393111e-05)
# (u'NAICS_CODE_ICS BUILDERS, INC.', 8.062220118350052e-05)
# ('SOC_CODE_43-4171', 8.06207304960117e-05)
# ('NAICS_CODE_561210', 8.047158214646663e-05)
# (u'NAICS_CODE_TRINITY CONSULTING, INC', 8.035631910914341e-05)
# ('NAICS_CODE_333294', 8.033101472184272e-05)
# (u'NAICS_CODE_GNU LEGACY L.L.C.', 8.015662038703834e-05)
# (u'NAICS_CODE_VIKING RIVER CRUISES, INC.', 8.012607020597023e-05)
# (u'NAICS_CODE_CLIKHOME,INC.', 8.011465059234569e-05)
# ('NAICS_CODE_532000', 7.993761807525373e-05)
# ('NAICS_CODE_424930', 7.977573238135608e-05)
# (u'NAICS_CODE_IMMIGRATION SOLUTIONS LLC', 7.97485096233394e-05)
# (u'NAICS_CODE_MOON COLLECTION, INC.', 7.969756427736563e-05)
# (u'NAICS_CODE_SABOOR WAIZUN MEDICAL PC', 7.966772844374292e-05)
# ('NAICS_CODE_112320', 3.555059301678568e-10)
# ('NAICS_CODE_11199', 3.5203231671701545e-10)
# ('NAICS_CODE_112910', 3.0461335973799925e-10)
# ('NAICS_CODE_332100', 2.9510437178843053e-10)
# ('SOC_CODE_29-2092', 2.826451906735847e-10)
# (u'NAICS_CODE_PEDIATRIC ASSOCIATES INC. OF BROCKTON', 2.791752780415931e-10)
# ('NAICS_CODE_22133', 2.767392610527065e-10)
# ('NAICS_CODE_31135', 2.744709886637514e-10)
# ('NAICS_CODE_51321', 2.67417782709307e-10)
# (u'NAICS_CODE_ALISHA TRIMBLE LLC', 2.653374436164347e-10)
# ('NAICS_CODE_33242', 2.502841655796659e-10)
# ('NAICS_CODE_236110', 2.46751624010626e-10)
# ('NAICS_CODE_32615', 2.4148144518081455e-10)
# ('SOC_CODE_39-2021', 2.346577249515815e-10)
# ('NAICS_CODE_445510', 2.2691547640141465e-10)
# ('NAICS_CODE_311823', 2.0716030184957952e-10)
# ('NAICS_CODE_32900', 1.9990060944483208e-10)
# ('NAICS_CODE_486110', 1.910541092339456e-10)
# ('NAICS_CODE_334500', 1.8174800569532251e-10)
# ('NAICS_CODE_333285', 1.7375187881467786e-10)
# ('NAICS_CODE_327200', 1.7227839674220484e-10)
# (u'NAICS_CODE_ON POINT TECHNOLOGY, LLC', 1.360477631578546e-10)
# ('NAICS_CODE_623119', 1.3499195749592882e-10)
# (u'NAICS_CODE_MAXX SPORTS TECHNOLOGIES LTD.', 1.3059793768713742e-10)
# (u'NAICS_CODE_INDIGO SKY ENTERPRISE INC.', 1.2565691399051818e-10)
# ('NAICS_CODE_325000', 1.2299146489848642e-10)
# ('NAICS_CODE_44229', 1.1846091510889255e-10)
# (u'NAICS_CODE_NEAR WEST SIDE COMMUNITY DEVELOPMENT CORPORATION', 1.1142782169273555e-10)
# (u'NAICS_CODE_F&R CONSULTANCY LLC', 9.174492987496912e-11)
# (u'NAICS_CODE_TOWERIQ INC', 8.361991057554964e-11)
# ('NAICS_CODE_423400', 7.215081812057641e-11)
# ('SOC_CODE_43-4151', 6.666467667456232e-11)
# ('NAICS_CODE_291069', 6.05771810277268e-11)
# ('NAICS_CODE_115113', 5.402283099557609e-11)
# (u'NAICS_CODE_UNITED STATES MILITARY ACADEMY', 3.543581059228488e-11)
# ('NAICS_CODE_51120', 3.2876790572401716e-11)
# ('NAICS_CODE_311500', 2.8276762697328475e-11)
# ('NAICS_CODE_327113', 2.2827214443672462e-11)
# ('NAICS_CODE_42459', 5.964102400361908e-12)

# %%
import pickle
with open('/tmp/feature_importances_first_800k_rfc.pickle', 'wb') as f:
    pickle.dump(sorted_result, f, protocol=pickle.HIGHEST_PROTOCOL)
with open('/tmp/feature_importances_first_800k_rfc_dict.pickle', 'wb') as f:
    pickle.dump(nonzero_features, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Output the trained model to a pickle file in case we need it in the future

# %%
from sklearn.externals import joblib
joblib.dump(rfc, 'rfc.pkl', compress=9)
joblib.dump(clf, 'tree.pkl', compress=9)

# import cPickle
# with open('rfc_cpickle.pkl', 'wb') as pkl:
#     cPickle.dump(rfc, pkl)
# with open('tree_cpickle.pkl', 'wb') as pkl:
#     cPickle.dump(clf, pkl)

# %% [markdown]
# To load the pre-trained model, run the cell below.

# %%
rfc = joblib.load('rfc.pkl')
clf = joblib.load('tree.pkl')

# with open('rfc_cpickle.pkl', 'rb') as pkl:
#     rfc = cPickle.load(pkl)
# with open('tree_cpickle.pkl', 'rb') as pkl:
#     clf = cPickle.load(pkl)

# %% [markdown]
# Evaluate stats for the entire test set

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, fbeta_score, accuracy_score, confusion_matrix
# print(rfc_pred)

print("** Decision tree Classifier Scores (OVERALL testset)")
print("Precision: %s" % precision_score(y_test, tree_pred))
print("Recall: %s"% recall_score(y_test, tree_pred))
print("Accuracy score: %s"% accuracy_score(y_test, tree_pred))
print("F-1 score: %s"% f1_score(y_test, tree_pred))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_test, tree_pred, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_test, tree_pred, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_test, tree_pred))
print("\n")
print("** Random Forest Classifier Scores (OVERALL testset)")
print("Precision: %s"% precision_score(y_test, rfc_pred))
print("Recall: %s"% recall_score(y_test, rfc_pred))
print("Accuracy score: %s"% accuracy_score(y_test, rfc_pred))
print("F-1 score: %s"% f1_score(y_test, rfc_pred))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_test, rfc_pred, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_test, rfc_pred, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_test, rfc_pred))
# Out:
# ** Decision tree Classifier Scores (OVERALL testset)
# Precision: 0.606166783461808
# Recall: 0.34808853118712274
# Accuracy score: 0.9785590053160304
# F-1 score: 0.44222903885480574
# F-beta score with beta=0.5: 0.5278896619065055
# F-beta score with beta=0.2: 0.5893605870020965
# Confusion Matrix:
# [[296162   1686]
#  [  4860   2595]]
#
#
# ** Random Forest Classifier Scores (OVERALL testset)
# Precision: 0.6385118149824032
# Recall: 0.340710932260228
# Accuracy score: 0.9791911641877086
# F-1 score: 0.4443278229685997
# F-beta score with beta=0.5: 0.54350151923653
# F-beta score with beta=0.2: 0.617744726626444
# Confusion Matrix:
# [[296410   1438]
#  [  4915   2540]]

# %%
import numpy as np
ones_index = y_test.nonzero()
x_ones = X_test.iloc[ones_index]
y_ones = np.take(y_test, ones_index)[0]

tree_pred_oneonly = clf.predict(x_ones)
rfc_pred_oneonly = rfc.predict(x_ones)

# %% [markdown]
# Evaluate stats for testset with label 1 (DENIED cases only)

# %%
print("** Decision tree Classifier Scores (Only rows with label DENIED->1)")
print("Precision: %s" % precision_score(y_ones, tree_pred_oneonly))
print("Recall: %s"% recall_score(y_ones, tree_pred_oneonly))
print("Accuracy score: %s"% accuracy_score(y_ones, tree_pred_oneonly))
print("F-1 score: %s"% f1_score(y_ones, tree_pred_oneonly))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_ones, tree_pred_oneonly, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_ones, tree_pred_oneonly, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_ones, tree_pred_oneonly))
print("\n")
print("** Random Forest Classifier Scores (Only rows with label DENIED->1)")
print("Precision: %s"% precision_score(y_ones, rfc_pred_oneonly))
print("Recall: %s"% recall_score(y_ones, rfc_pred_oneonly))
print("Accuracy score: %s"% accuracy_score(y_ones, rfc_pred_oneonly))
print("F-1 score: %s"% f1_score(y_ones, rfc_pred_oneonly))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_ones, rfc_pred_oneonly, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_ones, rfc_pred_oneonly, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_ones, rfc_pred_oneonly))
# Out:
# ** Decision tree Classifier Scores (Only rows with label DENIED->1)
# Precision: 1.0
# Recall: 0.34808853118712274
# Accuracy score: 0.34808853118712274
# F-1 score: 0.5164179104477612
# F-beta score with beta=0.5: 0.727502102607233
# F-beta score with beta=0.2: 0.9328079635006222
# Confusion Matrix:
# [[   0    0]
#  [4860 2595]]
#
#
# ** Random Forest Classifier Scores (Only rows with label DENIED->1)
# Precision: 1.0
# Recall: 0.340710932260228
# Accuracy score: 0.340710932260228
# F-1 score: 0.5082541270635318
# F-beta score with beta=0.5: 0.7209764405336362
# F-beta score with beta=0.2: 0.9307307448382779
# Confusion Matrix:
# [[   0    0]
#  [4915 2540]]

# %%
zeros_index = np.arange(len(y_test))[(y_test==0)]

x_zeros = X_test.iloc[zeros_index]
y_zeros = np.take(y_test, zeros_index)
tree_pred_zeroonly = clf.predict(x_zeros)
rfc_pred_zeroonly = rfc.predict(x_zeros)

# %% [markdown]
# Evaluate stats for testset with label 0 (CERTIFIED cases only)

# %%
print("** Decision tree Classifier Scores (Only rows with label CERTIFIED->0)")
print("Precision: %s" % precision_score(y_zeros, tree_pred_zeroonly))
print("Recall: %s"% recall_score(y_zeros, tree_pred_zeroonly))
print("Accuracy score: %s"% accuracy_score(y_zeros, tree_pred_zeroonly))
print("F-1 score: %s"% f1_score(y_zeros, tree_pred_zeroonly))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_zeros, tree_pred_zeroonly, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_zeros, tree_pred_zeroonly, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_zeros, rfc_pred_zeroonly))
print("\n")
print("** Random Forest Classifier Scores (Only rows with label CERTIFIED->0)")
print("Precision: %s"% precision_score(y_zeros, rfc_pred_zeroonly))
print("Recall: %s"% recall_score(y_zeros, rfc_pred_zeroonly))
print("Accuracy score: %s"% accuracy_score(y_zeros, rfc_pred_zeroonly))
print("F-1 score: %s"% f1_score(y_zeros, rfc_pred_zeroonly))
print("F-beta score with beta=0.5: %s"% fbeta_score(y_zeros, rfc_pred_zeroonly, beta=0.5))
print("F-beta score with beta=0.2: %s"% fbeta_score(y_zeros, rfc_pred_zeroonly, beta=0.2))
print("Confusion Matrix: \n%s"% confusion_matrix(y_zeros, rfc_pred_zeroonly))
# Out:
# ** Decision tree Classifier Scores (Only rows with label CERTIFIED->0)
# Precision: 0.0
# Recall: 0.0
# Accuracy score: 0.9943393945905294
# F-1 score: 0.0
# F-beta score with beta=0.5: 0.0
# F-beta score with beta=0.2: 0.0
# Confusion Matrix:
# [[296410   1438]
#  [     0      0]]
#
#
# ** Random Forest Classifier Scores (Only rows with label CERTIFIED->0)
# Precision: 0.0
# Recall: 0.0
# Accuracy score: 0.9951720340576401
# F-1 score: 0.0
# F-beta score with beta=0.5: 0.0
# F-beta score with beta=0.2: 0.0
# Confusion Matrix:
# [[296410   1438]
#  [     0      0]]

# %% [markdown]
# Show ratio between the two classes in the entire dataset (before split into train and test set)

# %%
status_stats = df.groupby('CASE_STATUS').size().to_frame()
status_stats['percentage'] = status_stats[0] / status_stats[0].sum()
print(status_stats)
# Out:
#                    0  percentage
# CASE_STATUS
# CERTIFIED    1489240    0.975582
# DENIED         37274    0.024418
